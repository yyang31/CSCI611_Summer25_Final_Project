# %% [markdown]
# # Safety First - Hard Hat Detection

# %% [markdown]
# ---
# ## Project Proposal
#
# ### Team Member
#
# - Stanley Yang
# - Lennard Vanderspek
#
# ### Description
#
# Workplace safety is very important but often overlooked. Most important way to keep workers
# safe is by wearing a hard hat. This project will utilize Convolution Neural Net and YOLO to help
# detect whether workers are wearing a hard hat or not.
#
# #### Machine Learning Topics Used:
#
# - Convolution Neural Net
# - YOLO
#
# ### Expected Outcome
#
# A trained model that is able to detect whether workers are wearing a hard hat or not by
# implementing YOLO using PyTorch. We are hoping to utilize the model to bring more awareness
# to workplace safety.

# %% [markdown]
# ---
#
# ## Use CUDA if Available

# %%
import torch

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print("CUDA is not available.  Training on CPU ...")
else:
    print(f"CUDA is available!  Training on GPU ({torch.cuda.get_device_name(0)}) ...")
# Out:
# CUDA is available!  Training on GPU (NVIDIA GeForce RTX 3070) ...

# %% [markdown]
# ---
# ## Load the Data

# %% [markdown]
# ### Create Custom Dataset Class

# %%
from torch.utils.data import Dataset
import cv2
import torchvision.transforms as transforms
import os
from PIL import Image

# specify the image classes
CLASSES = ['head', 'helmet', 'person']
NUM_CLASSES = len(CLASSES)

def yolo_collate_fn(batch):
    images, labels = zip(*batch)
    images = torch.stack(images, dim=0)
    # Pad labels to the max number of objects in the batch
    max_objs = max(label.shape[0] for label in labels)
    padded_labels = []
    for label in labels:
        pad_size = max_objs - label.shape[0]
        if pad_size > 0:
            # Pad with -1
            padded = torch.nn.functional.pad(label, (0, 0, 0, pad_size), value=-1)
        else:
            padded = label
        padded_labels.append(padded)
    labels = torch.stack(padded_labels, dim=0)
    return images, labels

class custom_dataset(Dataset):
    def __init__(self, image_path, label_path, transform:transforms = None, number_image_to_load=None):
        self.image_path = image_path
        self.label_path = label_path
        self.transform = transform

        if number_image_to_load is None:
            # Load images and labels
            self.images = sorted(os.listdir(image_path))
            self.labels = sorted(os.listdir(label_path))
        else:
            # Load a limited number of images and labels
            self.images = sorted(os.listdir(image_path))[:number_image_to_load]
            self.labels = sorted(os.listdir(label_path))[:number_image_to_load]
    
    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        image_name = self.images[index]
        label_name = self.labels[index]

        # Ensure the label file corresponds to the image file
        if not label_name.startswith(image_name.split('.')[0]):
            raise ValueError(f"Label file {label_name} does not match image file {image_name}")

        # Load the image
        image = cv2.imread(os.path.join(self.image_path, image_name))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)
        if self.transform:
            image = self.transform(image)

        # Load the label
        # Example INPUT with format [class_id, x_center, y_center, width, height]
        # 1 0.502 0.6506024096385542 0.032 0.060240963855421686
        #
        # Example converted OUTPUT with format [x_center, y_center, width, height, confidence, class_0, class_1, class_2]
        # 0.502 0.6506024096385542 0.032 0.060240963855421686 1 0.0 1.0 0.0
        labels = []
        with open(os.path.join(self.label_path, label_name), 'r') as f:
            for line in f.readlines():
                parts = line.strip().split()
                if len(parts) != 5:
                    print(f"Skipping invalid label line: {line.strip()}")
                    continue
                class_id = int(parts[0])
                x_center = float(parts[1])
                y_center = float(parts[2])
                width = float(parts[3])
                height = float(parts[4])

                # Confidence = 1.0 for ground truth
                conf = 1.0

                # One-hot encoding for class
                one_hot_class = [0.0] * NUM_CLASSES
                one_hot_class[class_id] = 1.0

                # Final label vector
                labels.append([x_center, y_center, width, height, conf] + one_hot_class)

        return image, torch.tensor(labels, dtype=torch.float32)

# %% [markdown]
# ### Load the Data using Custom Dataset Class

# %%
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler

# TODO: Need to adjust the default values

# number of subprocesses to use for data loading
num_workers = 0

# how many samples per batch to load
batch_size = 64

# percentage of training set to use as validation
valid_size = 0.2

# number of data to load (None for all)
train_data_to_load = 2000   # at least 2000 for a good training
test_data_to_load = None

# resize the images to this size
# smaller size means faster training
# larger size means better detection on small objects
image_size = (256, 256)

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose(
    [
        transforms.Resize(image_size),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ]
)

# load the data set
train_data = custom_dataset(
    image_path="data-yolo-v7/train/images",
    label_path="data-yolo-v7/train/labels",
    transform=transform,
    number_image_to_load=train_data_to_load,
)
test_data = custom_dataset(
    image_path="data-yolo-v7/test/images",
    label_path="data-yolo-v7/test/labels",
    transform=transform,
    number_image_to_load=test_data_to_load,
)
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=batch_size,
    sampler=train_sampler,
    num_workers=num_workers,
    collate_fn=yolo_collate_fn,
    pin_memory=train_on_gpu,
)
valid_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=batch_size,
    sampler=valid_sampler,
    num_workers=num_workers,
    collate_fn=yolo_collate_fn,
    pin_memory=train_on_gpu,
)
test_loader = torch.utils.data.DataLoader(
    test_data,
    batch_size=batch_size,
    num_workers=num_workers,
    collate_fn=yolo_collate_fn,
    pin_memory=train_on_gpu,
)

# %% [markdown]
# ### Custom Bounding Box Drawing

# %%
from matplotlib import patches


def draw_bounding_boxes(ax, labels, img_size, class_names, color="lime", is_prediction=True):
    h, w = img_size

    for box in labels:
        # Only skip if ground truth and it's padding
        if not is_prediction and box[0] == -1:
            continue

        x_center, y_center, box_w, box_h = box[:4]

        x = (x_center - box_w / 2) * w
        y = (y_center - box_h / 2) * h
        width = box_w * w
        height = box_h * h

        if box.shape[0] > 5:
            class_id = torch.argmax(box[5:]).item()
        else:
            class_id = int(box[0]) if not is_prediction else 0

        label_text = class_names[class_id] if class_id < len(class_names) else "?"

        if is_prediction and box.shape[0] > 4:
            label_text += f" {box[4].item():.2f}"

        rect = patches.Rectangle(
            (x, y), width, height, linewidth=2, edgecolor=color, facecolor="none"
        )
        ax.add_patch(rect)

        ax.text(
            x,
            max(y - 5, 0),
            label_text,
            color=color,
            backgroundcolor="black",
            fontsize=10,
        )

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# obtain one batch of training images
dataiter = iter(train_loader)

#images, labels = dataiter.next() #python, torchvision version match issue
images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 25))

# display 2 images
for idx in range(2):
    ax = fig.add_subplot(1, 2, idx+1, xticks=[], yticks=[])
    image_np = np.transpose(images[idx], (1, 2, 0))  # shape: (H, W, C)
    image_np = image_np * 0.5 + 0.5  # unnormalize
    ax.imshow(image_np)

    label = labels[idx]
    valid_labels = label[~(label == -1).all(dim=1)]
    draw_bounding_boxes(ax, valid_labels, img_size=(image_np.shape[0], image_np.shape[1]), class_names=CLASSES, is_prediction=False)

    # filter out padding (rows where all values are -1)

    
    valid_labels = label[~(label == -1).all(axis=1)]
    ax.set_title(f'Labels:\n{valid_labels}')

plt.show()

# %% [markdown]
# ### View an Image in More Detail
#
# Showing the normalized red, green, and blue (RGB) color channels as three separate, gray scale intensity images.

# %%
rgb_img = np.squeeze(images[0])
channels = ["red channel", "green channel", "blue channel"]
step = 10  # visualizing in steps of 10 pixels due to large image size

fig = plt.figure(figsize=(36, 36))
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap="gray")
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max() / 2.5
    for x in range(0, width, step):
        for y in range(0, height, step):
            val = round(img[x][y], 2) if img[x][y] != 0 else 0
            ax.annotate(
                str(val),
                xy=(y, x),
                horizontalalignment="center",
                verticalalignment="center",
                size=8,
                color="white" if img[x][y] < thresh else "black",
            )

plt.show()

# %% [markdown]
# ---
# ## Define the Network Architecture

# %%
import torch.nn as nn

# TOD: adjust the default values
NUMBER_ANCHORS = 3
GRID_SIZE = 7

class yolo(nn.Module):
    # TODO: adjust the default values
    def __init__(self, num_anchors=NUMBER_ANCHORS, grid_size=GRID_SIZE, NUM_CLASSES=NUM_CLASSES):
        super(yolo, self).__init__()

        self.num_anchors = num_anchors
        self.num_classes = NUM_CLASSES
        self.grid_size = grid_size

        self.convolution_layers = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((self.grid_size, self.grid_size))
        )

        self.detection_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(256 * grid_size * grid_size, grid_size * grid_size * num_anchors * (5 + NUM_CLASSES))
        )

    def forward(self, x):
        features = self.convolution_layers(x)
        predictions = self.detection_layers(features)
        predictions = predictions.view(-1, self.grid_size, self.grid_size, self.num_anchors, 5 + self.num_classes)

        # Clone before applying activations to avoid in-place modification issues during back probgation
        out = predictions.clone()

        out[..., 0:2] = torch.sigmoid(predictions[..., 0:2])                     # x, y
        out[..., 4]   = torch.sigmoid(predictions[..., 4])                       # objectness
        out[..., 2:4] = torch.sigmoid(predictions[..., 2:4])           # w, h
        out[..., 5:]  = torch.softmax(predictions[..., 5:], dim=-1)             # class probs

        return out



# create a complete CNN
model = yolo()
print(model)

# output total number of parameters
print(
    f"Total parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# yolo(
#   (convolution_layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): AdaptiveAvgPool2d(output_size=(7, 7))
#   )
#   (detection_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=12544, out_features=1176, bias=True)
#   )
# )
# Total parameters: 15124632

# %% [markdown]
# ---
# ## Specify Loss Function and Optimizer

# %% [markdown]
# ### Create Custom Loss Function for YOLO
#
# YOLO loss function is defined as following ([reference](https://www.geeksforgeeks.org/computer-vision/yolov3-from-scratch-using-pytorch/)):
#
# ![loss function](./images/yolo_loss_function.png)

# %%
LAMBDA_COORD = 5.0
LAMBDA_OBJ = 1.0
LAMBDA_NOOBJ = 0.01
LAMBDA_CLASS = 1.0

def calculate_iou(pred, target):
    pred_x1 = pred[0] - pred[2] / 2
    pred_y1 = pred[1] - pred[3] / 2
    pred_x2 = pred[0] + pred[2] / 2
    pred_y2 = pred[1] + pred[3] / 2

    target_x1 = target[0] - target[2] / 2
    target_y1 = target[1] - target[3] / 2
    target_x2 = target[0] + target[2] / 2
    target_y2 = target[1] + target[3] / 2

    inter_x1 = torch.max(pred_x1, target_x1)
    inter_y1 = torch.max(pred_y1, target_y1)
    inter_x2 = torch.min(pred_x2, target_x2)
    inter_y2 = torch.min(pred_y2, target_y2)

    inter_area = (inter_x2 - inter_x1).clamp(0) * (inter_y2 - inter_y1).clamp(0)
    pred_area = (pred_x2 - pred_x1) * (pred_y2 - pred_y1)
    target_area = (target_x2 - target_x1) * (target_y2 - target_y1)
    union = pred_area + target_area - inter_area

    return inter_area / (union + 1e-6)

def custom_loss(predictions, targets, anchors, confidence_threshold, iou_threshold,
                lambda_coord=LAMBDA_COORD, lambda_obj=LAMBDA_OBJ,
                lambda_noobj=LAMBDA_NOOBJ, lambda_class=LAMBDA_CLASS):
    batch_size, grid_height, grid_width, num_anchors, pred_len = predictions.shape
    device = predictions.device
    losses = []

    coord_total = 0.0
    obj_total = 0.0
    noobj_total = 0.0
    class_total = 0.0

    one_tensor = torch.tensor(1.0, device=device)
    zero_tensor = torch.tensor(0.0, device=device)

    for i in range(batch_size):
        matched = []
        used_targets = set()
        pred = predictions[i]
        target = targets[i]

        for target_i, target_box in enumerate(target):
            gx, gy = target_box[0], target_box[1]
            # grid_x = int(gx * grid_width)
            # grid_y = int(gy * grid_height)
            grid_x = min(grid_width - 1, max(0, int(gx * grid_width)))
            grid_y = min(grid_height - 1, max(0, int(gy * grid_height)))


            best_iou = 0
            best_anchor = -1

            for anchor_idx in range(num_anchors):
                pred_box = pred[grid_y, grid_x, anchor_idx]

                anchor_w, anchor_h = anchors[anchor_idx]
                px = torch.sigmoid(pred_box[0])
                py = torch.sigmoid(pred_box[1])
                pw = torch.exp(pred_box[2]) * anchor_w
                ph = torch.exp(pred_box[3]) * anchor_h
                pred_box_decoded = torch.tensor([px, py, pw, ph])

                iou = calculate_iou(pred_box_decoded, target_box[:4])
                if iou > best_iou:
                    best_iou = iou
                    best_anchor = anchor_idx

            # best_anchor_idx = best_anchor
            if target_i not in used_targets and best_iou > iou_threshold and best_anchor != -1:
                matched.append((grid_y, grid_x, best_anchor, target_i))
                used_targets.add(target_i)

            # if best_iou > iou_threshold and best_anchor != -1:
            #     matched.append((grid_y, grid_x, best_anchor, target_i))
            #     used_targets.add(target_i)

        for gy in range(grid_height):
            for gx in range(grid_width):
                for a in range(num_anchors):
                    pred_box = pred[gy, gx, a]
                    pred_conf = torch.sigmoid(pred_box[4])

                    match = next(((my, mx, ma, ti) for (my, mx, ma, ti) in matched if my == gy and mx == gx and ma == a), None)

                    if match:
                        _, _, _, target_i = match
                        target_box = target[target_i]

                        anchor_w, anchor_h = anchors[a]
                        px = torch.sigmoid(pred_box[0])
                        py = torch.sigmoid(pred_box[1])
                        pw = (torch.exp(pred_box[2]) * anchor_w).clamp(min=1e-6)
                        ph = (torch.exp(pred_box[3]) * anchor_h).clamp(min=1e-6)
                        pred_box_decoded = torch.stack([px, py, pw, ph])

                        box_loss = (
                            torch.nn.functional.mse_loss(px, target_box[0]) +
                            torch.nn.functional.mse_loss(py, target_box[1]) +
                            torch.nn.functional.mse_loss(torch.sqrt(pw + 1e-6), torch.sqrt(target_box[2] + 1e-6)) +
                            torch.nn.functional.mse_loss(torch.sqrt(ph + 1e-6), torch.sqrt(target_box[3] + 1e-6))
                        )

                        iou_score = calculate_iou(pred_box_decoded, target_box[:4])
                        obj_loss = torch.nn.functional.mse_loss(pred_conf, iou_score.detach())

                        class_loss = torch.nn.functional.binary_cross_entropy(torch.sigmoid(pred_box[5:]), target_box[5:])

                        coord_total += lambda_coord * box_loss
                        obj_total += lambda_obj * obj_loss
                        class_total += lambda_class * class_loss

                        losses.append(lambda_coord * box_loss + lambda_obj * obj_loss + lambda_class * class_loss)
                    else:
                        noobj_loss = torch.nn.functional.mse_loss(pred_conf, zero_tensor)
                        noobj_total += lambda_noobj * noobj_loss
                        losses.append(lambda_noobj * noobj_loss)

    total_loss = torch.stack(losses).sum() / batch_size if losses else torch.tensor(0.0, device=device)
    print(f"matches: {len(matched)} / {len(target)}")

    if torch.is_grad_enabled():
        assert total_loss.requires_grad, "Loss does not require grad!"

    return total_loss, coord_total, obj_total, noobj_total, class_total

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR

# specify loss function (categorical cross-entropy)
criterion = custom_loss

# specify optimizer
# TODO: adjust the learning rate
# smaller lr means it requires more epochs to improve
# larger lr means it may overshoot and become unstable
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ---
# ## Train the Network

# %% [markdown]
# ### Variables Needed for Training

# %%
valid_loss_min = np.inf  # track change in validation loss
total_epochs_run = 0

# TODO: Need to adjust base on the anchor size
anchors = torch.tensor([
    [0.10, 0.15],  # Small object
    [0.20, 0.30],  # Medium object
    [0.40, 0.50]   # Larger object
], dtype=torch.float32)

# %% [markdown]
# ### Can Run the Following Section as Many time as wanted

# %%
import time
from datetime import timedelta

start_time = time.time()

# TODO: update the following variable
n_epochs = 10   # number of epochs to run for this iteration
CONFIDENCE_THRESHOLD = 0.1

IOU_THRESHOLD = NEW_IOU_THRESHOLD = IOU_START = 0
IOU_END = 0.5
IOU_RAMPUP_EPOCHS = 10

# load the model if this is a continuation of training
if total_epochs_run > 0:
    print(f"Continuing training from epoch {total_epochs_run + 1}")
    model.load_state_dict(torch.load("model_trained.pt", weights_only=True))

for epoch in range(1, n_epochs + 1):
    IOU_THRESHOLD = NEW_IOU_THRESHOLD
    print(f"Epoch {total_epochs_run + epoch}/{total_epochs_run + n_epochs} - IOU threshold: {IOU_THRESHOLD:.3f}")

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0

    ###################
    # train the model #
    ###################
    print("Training...")
    model.train()
    for batch_idx, (images, targets) in enumerate(train_loader):
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            images, targets = images.cuda(), targets.cuda()

        # clear the gradients of all optimized variables
        optimizer.zero_grad()

        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(images)

        # calculate the batch loss
        loss, coord_loss, obj_loss, noobj_loss, class_loss = criterion(output, targets, anchors, CONFIDENCE_THRESHOLD, IOU_THRESHOLD)
        print(f"[Epoch {epoch} | Batch {batch_idx}] Total: {loss.item():.4f} | Coord: {coord_loss:.4f} | Obj: {obj_loss:.4f} | NoObj: {noobj_loss:.4f} | Class: {class_loss:.4f}")

        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward(retain_graph=True)

        # clip the gradients to avoid exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)

        # perform a single optimization step (parameter update)
        optimizer.step()

        # update training loss
        train_loss += loss.item() * images.size(0)

    ######################
    # validate the model #
    ######################
    print("Validating...")
    model.eval()
    for batch_idx, (images, targets) in enumerate(valid_loader):
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            images, targets = images.cuda(), targets.cuda()

        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(images)

        # calculate the batch loss
        loss, coord_loss, obj_loss, noobj_loss, class_loss = criterion(output, targets, anchors, CONFIDENCE_THRESHOLD, IOU_THRESHOLD)

        # update average validation loss
        valid_loss += loss.item() * images.size(0)

    # calculate average losses
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(valid_loader.sampler)

    # print training/validation statistics
    print(f"Training Loss: {train_loss}")
    print(f"Validation Loss: {valid_loss}")

    # save model if validation loss has decreased
    if valid_loss > 0 and valid_loss <= valid_loss_min:
        print(f"Validation loss has decreased from {valid_loss_min} to {valid_loss}")
        print("Saving model ...")
        torch.save(model.state_dict(), "model_trained.pt")
        valid_loss_min = valid_loss
    
    # update IOU if this is not the first epoch
    if epoch <= IOU_RAMPUP_EPOCHS:
        ramp_factor = epoch / IOU_RAMPUP_EPOCHS
        NEW_IOU_THRESHOLD = IOU_START + (IOU_END - IOU_START) * (ramp_factor ** 4)
        NEW_IOU_THRESHOLD = min(IOU_THRESHOLD, IOU_END)

    print("\n")

total_epochs_run += n_epochs

end_time = time.time()
total_duration = end_time - start_time
print(f"Total Time for Training: {str(timedelta(seconds=int(total_duration)))}")
# Out:
# Epoch 1/10 - IOU threshold: 0.000
# Training...
# matches: 3 / 12
# [Epoch 1 | Batch 0] Total: 11.9281 | Coord: 505.7809 | Obj: 67.3139 | NoObj: 35.6273 | Class: 154.6773
# matches: 7 / 20
# [Epoch 1 | Batch 1] Total: 6.1368 | Coord: 214.5463 | Obj: 33.9734 | NoObj: 23.2604 | Class: 120.9742
# matches: 4 / 11
# [Epoch 1 | Batch 2] Total: 4.9369 | Coord: 160.2294 | Obj: 27.9788 | NoObj: 23.1415 | Class: 104.6148
# matches: 4 / 13
# [Epoch 1 | Batch 3] Total: 5.3338 | Coord: 179.4236 | Obj: 30.5437 | NoObj: 23.1104 | Class: 108.2869
# matches: 1 / 18
# [Epoch 1 | Batch 4] Total: 5.6006 | Coord: 187.2937 | Obj: 31.5864 | NoObj: 23.0853 | Class: 116.4746
# matches: 1 / 14
# [Epoch 1 | Batch 5] Total: 5.3895 | Coord: 184.2799 | Obj: 29.6402 | NoObj: 23.1128 | Class: 107.8927
# matches: 4 / 16
# [Epoch 1 | Batch 6] Total: 5.3638 | Coord: 179.6644 | Obj: 30.0984 | NoObj: 23.1128 | Class: 110.4080
# matches: 4 / 18
# [Epoch 1 | Batch 7] Total: 5.8966 | Coord: 195.1021 | Obj: 32.3429 | NoObj: 23.0628 | Class: 126.8722
# matches: 3 / 16
# [Epoch 1 | Batch 8] Total: 5.3362 | Coord: 168.4226 | Obj: 30.4098 | NoObj: 23.0678 | Class: 119.6185
# matches: 8 / 13
# [Epoch 1 | Batch 9] Total: 4.8775 | Coord: 153.5473 | Obj: 28.2415 | NoObj: 23.1103 | Class: 107.2641
# matches: 0 / 20
# [Epoch 1 | Batch 10] Total: 6.0811 | Coord: 211.2420 | Obj: 34.8018 | NoObj: 23.0728 | Class: 120.0736
# matches: 5 / 16
# [Epoch 1 | Batch 11] Total: 4.7994 | Coord: 150.4408 | Obj: 27.8820 | NoObj: 23.1303 | Class: 105.7102
# matches: 9 / 15
# [Epoch 1 | Batch 12] Total: 4.8881 | Coord: 163.3572 | Obj: 28.3607 | NoObj: 23.1453 | Class: 97.9778
# matches: 3 / 21
# [Epoch 1 | Batch 13] Total: 5.6733 | Coord: 187.2669 | Obj: 32.1809 | NoObj: 23.0728 | Class: 120.5737
# matches: 4 / 16
# [Epoch 1 | Batch 14] Total: 5.3035 | Coord: 174.3786 | Obj: 29.7630 | NoObj: 23.1028 | Class: 112.1783
# matches: 1 / 11
# [Epoch 1 | Batch 15] Total: 4.8496 | Coord: 159.3014 | Obj: 27.9015 | NoObj: 23.1303 | Class: 100.0437
# matches: 1 / 13
# [Epoch 1 | Batch 16] Total: 5.1452 | Coord: 174.2361 | Obj: 30.4223 | NoObj: 23.1253 | Class: 101.5100
# matches: 3 / 16
# [Epoch 1 | Batch 17] Total: 5.5846 | Coord: 188.2133 | Obj: 31.2114 | NoObj: 23.0853 | Class: 114.9076
# matches: 2 / 15
# [Epoch 1 | Batch 18] Total: 4.3035 | Coord: 133.9332 | Obj: 25.5229 | NoObj: 23.1578 | Class: 92.8119
# matches: 4 / 17
# [Epoch 1 | Batch 19] Total: 6.1883 | Coord: 218.5075 | Obj: 35.8061 | NoObj: 23.0628 | Class: 118.6729
# matches: 1 / 12
# [Epoch 1 | Batch 20] Total: 4.8173 | Coord: 162.7468 | Obj: 27.4123 | NoObj: 23.1378 | Class: 95.0107
# matches: 2 / 13
# [Epoch 1 | Batch 21] Total: 5.6256 | Coord: 186.3847 | Obj: 32.2758 | NoObj: 23.0703 | Class: 118.3067
# matches: 2 / 18
# [Epoch 1 | Batch 22] Total: 4.5399 | Coord: 147.5379 | Obj: 25.3540 | NoObj: 23.1503 | Class: 94.5114
# matches: 1 / 18
# [Epoch 1 | Batch 23] Total: 5.4846 | Coord: 178.4129 | Obj: 32.6116 | NoObj: 23.0853 | Class: 116.9076
# matches: 1 / 15
# [Epoch 1 | Batch 24] Total: 5.3657 | Coord: 182.7516 | Obj: 30.6833 | NoObj: 23.1253 | Class: 106.8432
# Validating...
# matches: 3 / 13
# matches: 1 / 11
# matches: 1 / 15
# matches: 4 / 16
# matches: 1 / 15
# matches: 2 / 16
# matches: 7 / 10
# Training Loss: 5.577987823486328
# Validation Loss: 5.1091667175292965
# Validation loss has decreased from inf to 5.1091667175292965
# Saving model ...
#
#
# Epoch 2/10 - IOU threshold: 0.000
# Training...
# matches: 1 / 18
# [Epoch 2 | Batch 0] Total: 6.3089 | Coord: 215.1459 | Obj: 36.3510 | NoObj: 23.0353 | Class: 129.2379
# matches: 2 / 21
# [Epoch 2 | Batch 1] Total: 6.0271 | Coord: 210.3226 | Obj: 34.7041 | NoObj: 23.0578 | Class: 117.6482
# matches: 6 / 9
# [Epoch 2 | Batch 2] Total: 4.3330 | Coord: 140.6804 | Obj: 24.8179 | NoObj: 23.1703 | Class: 88.6459
# matches: 3 / 15
# [Epoch 2 | Batch 3] Total: 5.3748 | Coord: 169.5064 | Obj: 30.8496 | NoObj: 23.0603 | Class: 120.5728
# matches: 1 / 13
# [Epoch 2 | Batch 4] Total: 5.2933 | Coord: 178.0303 | Obj: 29.8226 | NoObj: 23.1078 | Class: 107.8089
# matches: 2 / 12
# [Epoch 2 | Batch 5] Total: 5.3983 | Coord: 173.3792 | Obj: 30.9138 | NoObj: 23.0903 | Class: 118.1078
# matches: 2 / 15
# [Epoch 2 | Batch 6] Total: 4.8320 | Coord: 155.2019 | Obj: 27.5399 | NoObj: 23.1303 | Class: 103.3769
# matches: 3 / 16
# [Epoch 2 | Batch 7] Total: 5.5949 | Coord: 192.1709 | Obj: 32.1383 | NoObj: 23.0878 | Class: 110.6744
# matches: 1 / 11
# [Epoch 2 | Batch 8] Total: 5.0584 | Coord: 167.1164 | Obj: 29.6516 | NoObj: 23.1253 | Class: 103.8433
# matches: 5 / 16
# [Epoch 2 | Batch 9] Total: 6.4497 | Coord: 215.6150 | Obj: 36.0983 | NoObj: 23.0303 | Class: 138.0375
# matches: 1 / 18
# [Epoch 2 | Batch 10] Total: 5.2694 | Coord: 177.9265 | Obj: 30.7552 | NoObj: 23.1153 | Class: 105.4427
# matches: 3 / 18
# [Epoch 2 | Batch 11] Total: 5.8259 | Coord: 194.2711 | Obj: 34.0542 | NoObj: 23.0578 | Class: 121.4726
# matches: 1 / 12
# [Epoch 2 | Batch 12] Total: 5.2179 | Coord: 166.9059 | Obj: 30.2230 | NoObj: 23.1053 | Class: 113.7087
# matches: 0 / 16
# [Epoch 2 | Batch 13] Total: 4.8441 | Coord: 153.6482 | Obj: 27.3820 | NoObj: 23.1178 | Class: 105.8761
# matches: 0 / 13
# [Epoch 2 | Batch 14] Total: 4.7759 | Coord: 153.0062 | Obj: 27.4757 | NoObj: 23.1303 | Class: 102.0436
# matches: 2 / 14
# [Epoch 2 | Batch 15] Total: 5.1037 | Coord: 170.3663 | Obj: 29.2782 | NoObj: 23.1178 | Class: 103.8761
# matches: 1 / 14
# [Epoch 2 | Batch 16] Total: 4.6437 | Coord: 151.2647 | Obj: 26.0378 | NoObj: 23.1478 | Class: 96.7446
# matches: 2 / 20
# [Epoch 2 | Batch 17] Total: 4.7402 | Coord: 155.6568 | Obj: 27.3864 | NoObj: 23.1503 | Class: 97.1781
# matches: 1 / 17
# [Epoch 2 | Batch 18] Total: 4.7225 | Coord: 146.8167 | Obj: 26.5814 | NoObj: 23.1303 | Class: 105.7102
# matches: 4 / 13
# [Epoch 2 | Batch 19] Total: 5.3007 | Coord: 181.2222 | Obj: 29.1805 | NoObj: 23.1303 | Class: 105.7102
# matches: 0 / 16
# [Epoch 2 | Batch 20] Total: 5.0394 | Coord: 164.7188 | Obj: 29.0424 | NoObj: 23.1203 | Class: 105.6429
# matches: 3 / 13
# [Epoch 2 | Batch 21] Total: 5.7263 | Coord: 191.9252 | Obj: 32.8747 | NoObj: 23.0778 | Class: 118.6071
# matches: 0 / 20
# [Epoch 2 | Batch 22] Total: 5.1098 | Coord: 166.9292 | Obj: 28.9283 | NoObj: 23.0978 | Class: 108.0750
# matches: 0 / 13
# [Epoch 2 | Batch 23] Total: 5.2166 | Coord: 170.1820 | Obj: 30.9177 | NoObj: 23.0878 | Class: 109.6744
# matches: 2 / 18
# [Epoch 2 | Batch 24] Total: 5.5400 | Coord: 183.0701 | Obj: 31.7297 | NoObj: 23.0878 | Class: 116.6744
# Validating...
# matches: 6 / 13
# matches: 1 / 15
# matches: 4 / 16
# matches: 2 / 16
# matches: 6 / 11
# matches: 0 / 13
# matches: 2 / 11
# Training Loss: 5.269854793548584
# Validation Loss: 5.119706115722656
#
#
# Epoch 3/10 - IOU threshold: 0.001
# Training...
# matches: 5 / 18
# [Epoch 3 | Batch 0] Total: 5.4236 | Coord: 167.1816 | Obj: 31.4259 | NoObj: 23.0653 | Class: 125.4397
# matches: 1 / 17
# [Epoch 3 | Batch 1] Total: 4.9083 | Coord: 161.9363 | Obj: 27.4846 | NoObj: 23.1353 | Class: 101.5772
# matches: 0 / 16
# [Epoch 3 | Batch 2] Total: 4.6861 | Coord: 146.2981 | Obj: 26.7214 | NoObj: 23.1153 | Class: 103.7760
# matches: 1 / 15
# [Epoch 3 | Batch 3] Total: 5.3775 | Coord: 175.9320 | Obj: 31.2582 | NoObj: 23.0928 | Class: 113.8747
# matches: 2 / 14
# [Epoch 3 | Batch 4] Total: 5.1273 | Coord: 166.0938 | Obj: 29.9322 | NoObj: 23.1128 | Class: 109.0092
# matches: 1 / 21
# [Epoch 3 | Batch 5] Total: 5.7851 | Coord: 193.0286 | Obj: 33.6627 | NoObj: 23.0828 | Class: 120.4742
# matches: 1 / 18
# [Epoch 3 | Batch 6] Total: 5.0368 | Coord: 172.5161 | Obj: 29.0005 | NoObj: 23.1303 | Class: 97.7103
# matches: 8 / 13
# [Epoch 3 | Batch 7] Total: 5.8312 | Coord: 196.0586 | Obj: 33.5058 | NoObj: 23.0603 | Class: 120.5728
# matches: 3 / 14
# [Epoch 3 | Batch 8] Total: 4.8117 | Coord: 157.2705 | Obj: 28.5057 | NoObj: 23.1303 | Class: 99.0436
# matches: 2 / 10
# [Epoch 3 | Batch 9] Total: 4.8950 | Coord: 164.1633 | Obj: 27.3246 | NoObj: 23.1453 | Class: 98.6445
# matches: 5 / 11
# [Epoch 3 | Batch 10] Total: 4.9654 | Coord: 168.0895 | Obj: 28.7505 | NoObj: 23.1328 | Class: 97.8104
# matches: 1 / 15
# [Epoch 3 | Batch 11] Total: 4.7229 | Coord: 153.0509 | Obj: 27.6564 | NoObj: 23.1478 | Class: 98.4112
# matches: 1 / 17
# [Epoch 3 | Batch 12] Total: 5.1352 | Coord: 168.2500 | Obj: 28.9469 | NoObj: 23.1128 | Class: 108.3425
# matches: 1 / 13
# [Epoch 3 | Batch 13] Total: 5.0815 | Coord: 166.7358 | Obj: 29.4388 | NoObj: 23.1028 | Class: 105.9420
# matches: 1 / 12
# [Epoch 3 | Batch 14] Total: 4.6168 | Coord: 141.6213 | Obj: 26.2427 | NoObj: 23.1328 | Class: 104.4771
# matches: 12 / 16
# [Epoch 3 | Batch 15] Total: 5.9650 | Coord: 205.7222 | Obj: 34.8909 | NoObj: 23.0728 | Class: 118.0735
# matches: 3 / 16
# [Epoch 3 | Batch 16] Total: 4.9813 | Coord: 163.7889 | Obj: 28.2271 | NoObj: 23.1453 | Class: 103.6445
# matches: 1 / 13
# [Epoch 3 | Batch 17] Total: 6.3314 | Coord: 208.9571 | Obj: 37.3144 | NoObj: 23.0028 | Class: 135.9360
# matches: 2 / 15
# [Epoch 3 | Batch 18] Total: 5.6462 | Coord: 186.3513 | Obj: 31.5781 | NoObj: 23.0878 | Class: 120.3411
# matches: 3 / 20
# [Epoch 3 | Batch 19] Total: 5.4538 | Coord: 176.7789 | Obj: 31.5284 | NoObj: 23.0628 | Class: 117.6729
# matches: 6 / 20
# [Epoch 3 | Batch 20] Total: 4.6175 | Coord: 153.5733 | Obj: 25.5657 | NoObj: 23.1678 | Class: 93.2125
# matches: 2 / 11
# [Epoch 3 | Batch 21] Total: 5.7987 | Coord: 192.4018 | Obj: 32.6746 | NoObj: 23.0703 | Class: 122.9734
# matches: 6 / 15
# [Epoch 3 | Batch 22] Total: 4.8559 | Coord: 160.1373 | Obj: 28.6707 | NoObj: 23.1253 | Class: 98.8433
# matches: 0 / 14
# [Epoch 3 | Batch 23] Total: 5.3165 | Coord: 174.3128 | Obj: 29.7730 | NoObj: 23.0978 | Class: 113.0750
# matches: 5 / 18
# [Epoch 3 | Batch 24] Total: 5.5865 | Coord: 188.2472 | Obj: 31.6040 | NoObj: 23.0778 | Class: 114.6071
# Validating...
# matches: 2 / 11
# matches: 5 / 16
# matches: 2 / 12
# matches: 2 / 15
# matches: 1 / 11
# matches: 11 / 16
# matches: 3 / 10
# Training Loss: 5.238292808532715
# Validation Loss: 5.090490608215332
# Validation loss has decreased from 5.1091667175292965 to 5.090490608215332
# Saving model ...
#
#
# Epoch 4/10 - IOU threshold: 0.004
# Training...
# matches: 5 / 16
# [Epoch 4 | Batch 0] Total: 4.6749 | Coord: 150.0879 | Obj: 26.2876 | NoObj: 23.1378 | Class: 99.6773
# matches: 1 / 17
# [Epoch 4 | Batch 1] Total: 5.1470 | Coord: 162.3050 | Obj: 30.9062 | NoObj: 23.0903 | Class: 113.1079
# matches: 2 / 12
# [Epoch 4 | Batch 2] Total: 4.6248 | Coord: 145.9548 | Obj: 25.6782 | NoObj: 23.1428 | Class: 101.2110
# matches: 1 / 11
# [Epoch 4 | Batch 3] Total: 4.8045 | Coord: 157.1328 | Obj: 28.1027 | NoObj: 23.1403 | Class: 99.1108
# matches: 2 / 16
# [Epoch 4 | Batch 4] Total: 5.1050 | Coord: 165.7188 | Obj: 29.3423 | NoObj: 23.1178 | Class: 108.5428
# matches: 1 / 12
# [Epoch 4 | Batch 5] Total: 4.9565 | Coord: 155.6458 | Obj: 29.3177 | NoObj: 23.1078 | Class: 109.1422
# matches: 2 / 21
# [Epoch 4 | Batch 6] Total: 5.1412 | Coord: 157.2900 | Obj: 29.7038 | NoObj: 23.0703 | Class: 118.9734
# matches: 3 / 11
# [Epoch 4 | Batch 7] Total: 4.9698 | Coord: 162.0803 | Obj: 29.1491 | NoObj: 23.0978 | Class: 103.7417
# matches: 1 / 13
# [Epoch 4 | Batch 8] Total: 5.3720 | Coord: 180.2789 | Obj: 30.7127 | NoObj: 23.1053 | Class: 109.7087
# matches: 0 / 15
# [Epoch 4 | Batch 9] Total: 5.4730 | Coord: 176.8702 | Obj: 30.9757 | NoObj: 23.0878 | Class: 119.3410
# matches: 2 / 18
# [Epoch 4 | Batch 10] Total: 5.4926 | Coord: 174.8369 | Obj: 31.4432 | NoObj: 23.0753 | Class: 122.1736
# matches: 1 / 12
# [Epoch 4 | Batch 11] Total: 4.8981 | Coord: 166.4663 | Obj: 28.7634 | NoObj: 23.1403 | Class: 95.1108
# matches: 0 / 18
# [Epoch 4 | Batch 12] Total: 5.6145 | Coord: 185.2149 | Obj: 32.5304 | NoObj: 23.0753 | Class: 118.5070
# matches: 5 / 13
# [Epoch 4 | Batch 13] Total: 4.8348 | Coord: 155.1982 | Obj: 28.5683 | NoObj: 23.1178 | Class: 102.5428
# matches: 4 / 15
# [Epoch 4 | Batch 14] Total: 5.5088 | Coord: 181.0185 | Obj: 31.5267 | NoObj: 23.0778 | Class: 116.9405
# matches: 0 / 17
# [Epoch 4 | Batch 15] Total: 4.6964 | Coord: 160.1977 | Obj: 25.5561 | NoObj: 23.1703 | Class: 91.6459
# matches: 9 / 18
# [Epoch 4 | Batch 16] Total: 5.4059 | Coord: 172.9035 | Obj: 31.1848 | NoObj: 23.0828 | Class: 118.8074
# matches: 2 / 16
# [Epoch 4 | Batch 17] Total: 5.1221 | Coord: 168.0836 | Obj: 28.9456 | NoObj: 23.1128 | Class: 107.6759
# matches: 2 / 14
# [Epoch 4 | Batch 18] Total: 5.3716 | Coord: 180.3642 | Obj: 29.7345 | NoObj: 23.1103 | Class: 110.5757
# matches: 2 / 17
# [Epoch 4 | Batch 19] Total: 5.2889 | Coord: 173.1378 | Obj: 30.2823 | NoObj: 23.0953 | Class: 111.9749
# matches: 3 / 18
# [Epoch 4 | Batch 20] Total: 4.0410 | Coord: 123.9895 | Obj: 22.4101 | NoObj: 23.1803 | Class: 89.0465
# matches: 1 / 10
# [Epoch 4 | Batch 21] Total: 4.4901 | Coord: 144.0385 | Obj: 26.6660 | NoObj: 23.1503 | Class: 93.5114
# matches: 1 / 15
# [Epoch 4 | Batch 22] Total: 5.1395 | Coord: 169.4003 | Obj: 29.5359 | NoObj: 23.1178 | Class: 106.8762
# matches: 6 / 20
# [Epoch 4 | Batch 23] Total: 4.8287 | Coord: 159.9651 | Obj: 27.1765 | NoObj: 23.1478 | Class: 98.7446
# matches: 1 / 13
# [Epoch 4 | Batch 24] Total: 4.8308 | Coord: 155.1017 | Obj: 27.8409 | NoObj: 23.1478 | Class: 103.0780
# Validating...
# matches: 2 / 16
# matches: 2 / 11
# matches: 2 / 11
# matches: 3 / 16
# matches: 1 / 15
# matches: 2 / 15
# matches: 1 / 8
# Training Loss: 5.033302307128906
# Validation Loss: 4.922139892578125
# Validation loss has decreased from 5.090490608215332 to 4.922139892578125
# Saving model ...
#
#
# Epoch 5/10 - IOU threshold: 0.013
# Training...
# matches: 1 / 17
# [Epoch 5 | Batch 0] Total: 4.2824 | Coord: 131.0821 | Obj: 25.0709 | NoObj: 23.1728 | Class: 94.7461
# matches: 4 / 16
# [Epoch 5 | Batch 1] Total: 4.5958 | Coord: 140.8723 | Obj: 25.8811 | NoObj: 23.1353 | Class: 104.2439
# matches: 1 / 15
# [Epoch 5 | Batch 2] Total: 4.3499 | Coord: 135.5014 | Obj: 25.0519 | NoObj: 23.1628 | Class: 94.6788
# matches: 4 / 17
# [Epoch 5 | Batch 3] Total: 4.4526 | Coord: 142.3566 | Obj: 26.6136 | NoObj: 23.1503 | Class: 92.8448
# matches: 0 / 16
# [Epoch 5 | Batch 4] Total: 4.4645 | Coord: 135.3809 | Obj: 24.5563 | NoObj: 23.1453 | Class: 102.6445
# matches: 0 / 14
# [Epoch 5 | Batch 5] Total: 4.1402 | Coord: 122.9582 | Obj: 22.8659 | NoObj: 23.1703 | Class: 95.9793
# matches: 1 / 18
# [Epoch 5 | Batch 6] Total: 5.1655 | Coord: 163.1568 | Obj: 30.2897 | NoObj: 23.1053 | Class: 114.0420
# matches: 2 / 13
# [Epoch 5 | Batch 7] Total: 4.5912 | Coord: 145.8096 | Obj: 26.4672 | NoObj: 23.1478 | Class: 98.4113
# matches: 3 / 20
# [Epoch 5 | Batch 8] Total: 4.2377 | Coord: 131.9956 | Obj: 24.0169 | NoObj: 23.1879 | Class: 92.0136
# matches: 1 / 13
# [Epoch 5 | Batch 9] Total: 4.5310 | Coord: 138.4722 | Obj: 26.0555 | NoObj: 23.1453 | Class: 102.3111
# matches: 3 / 9
# [Epoch 5 | Batch 10] Total: 3.8659 | Coord: 108.7632 | Obj: 22.9661 | NoObj: 23.1753 | Class: 92.5128
# matches: 2 / 11
# [Epoch 5 | Batch 11] Total: 4.3368 | Coord: 130.9019 | Obj: 25.1697 | NoObj: 23.1378 | Class: 98.3440
# matches: 2 / 20
# [Epoch 5 | Batch 12] Total: 4.5858 | Coord: 137.5839 | Obj: 27.0416 | NoObj: 23.1228 | Class: 105.7431
# matches: 5 / 12
# [Epoch 5 | Batch 13] Total: 3.9517 | Coord: 117.7912 | Obj: 23.5339 | NoObj: 23.1728 | Class: 88.4128
# matches: 2 / 17
# [Epoch 5 | Batch 14] Total: 4.0964 | Coord: 121.7123 | Obj: 24.4372 | NoObj: 23.1753 | Class: 92.8463
# matches: 0 / 16
# [Epoch 5 | Batch 15] Total: 4.2152 | Coord: 130.2814 | Obj: 24.3650 | NoObj: 23.1778 | Class: 91.9463
# matches: 1 / 18
# [Epoch 5 | Batch 16] Total: 4.2605 | Coord: 132.4971 | Obj: 24.8735 | NoObj: 23.1578 | Class: 92.1451
# matches: 2 / 13
# [Epoch 5 | Batch 17] Total: 4.2178 | Coord: 134.4192 | Obj: 24.3932 | NoObj: 23.1778 | Class: 87.9464
# matches: 2 / 15
# [Epoch 5 | Batch 18] Total: 4.6900 | Coord: 144.5214 | Obj: 26.6462 | NoObj: 23.1178 | Class: 105.8762
# matches: 4 / 15
# [Epoch 5 | Batch 19] Total: 3.7070 | Coord: 115.0824 | Obj: 21.0163 | NoObj: 23.2029 | Class: 77.9478
# matches: 1 / 18
# [Epoch 5 | Batch 20] Total: 4.6581 | Coord: 144.9638 | Obj: 26.5465 | NoObj: 23.1328 | Class: 103.4770
# matches: 3 / 21
# [Epoch 5 | Batch 21] Total: 5.0239 | Coord: 159.4469 | Obj: 29.8046 | NoObj: 23.1003 | Class: 109.1751
# matches: 1 / 15
# [Epoch 5 | Batch 22] Total: 4.2271 | Coord: 126.8648 | Obj: 24.6524 | NoObj: 23.1428 | Class: 95.8776
# matches: 2 / 16
# [Epoch 5 | Batch 23] Total: 3.9582 | Coord: 118.5494 | Obj: 22.9840 | NoObj: 23.1778 | Class: 88.6131
# matches: 1 / 13
# [Epoch 5 | Batch 24] Total: 3.7357 | Coord: 106.9522 | Obj: 22.7038 | NoObj: 23.1854 | Class: 86.2468
# Validating...
# matches: 4 / 16
# matches: 2 / 15
# matches: 1 / 16
# matches: 2 / 15
# matches: 0 / 13
# matches: 2 / 12
# matches: 0 / 9
# Training Loss: 4.33363709449768
# Validation Loss: 4.213899688720703
# Validation loss has decreased from 4.922139892578125 to 4.213899688720703
# Saving model ...
#
#
# Epoch 6/10 - IOU threshold: 0.031
# Training...
# matches: 2 / 21
# [Epoch 6 | Batch 0] Total: 2.9277 | Coord: 71.5799 | Obj: 17.1038 | NoObj: 23.2404 | Class: 75.4500
# matches: 1 / 18
# [Epoch 6 | Batch 1] Total: 3.1693 | Coord: 74.8693 | Obj: 18.6079 | NoObj: 23.2079 | Class: 86.1482
# matches: 2 / 16
# [Epoch 6 | Batch 2] Total: 2.6791 | Coord: 67.0619 | Obj: 15.2724 | NoObj: 23.2754 | Class: 65.8521
# matches: 5 / 16
# [Epoch 6 | Batch 3] Total: 3.2932 | Coord: 87.1243 | Obj: 19.7695 | NoObj: 23.2204 | Class: 80.6488
# matches: 6 / 17
# [Epoch 6 | Batch 4] Total: 3.5755 | Coord: 92.6152 | Obj: 19.8338 | NoObj: 23.2004 | Class: 93.1810
# matches: 1 / 18
# [Epoch 6 | Batch 5] Total: 2.7504 | Coord: 68.6405 | Obj: 15.3349 | NoObj: 23.2654 | Class: 68.7849
# matches: 5 / 15
# [Epoch 6 | Batch 6] Total: 2.3876 | Coord: 55.6649 | Obj: 13.6036 | NoObj: 23.2854 | Class: 60.2527
# matches: 2 / 20
# [Epoch 6 | Batch 7] Total: 3.4111 | Coord: 91.2278 | Obj: 19.4985 | NoObj: 23.2054 | Class: 84.3813
# matches: 2 / 8
# [Epoch 6 | Batch 8] Total: 2.7197 | Coord: 73.5895 | Obj: 15.4455 | NoObj: 23.2729 | Class: 61.7520
# matches: 2 / 14
# [Epoch 6 | Batch 9] Total: 2.8415 | Coord: 74.2446 | Obj: 17.4066 | NoObj: 23.2529 | Class: 66.9508
# matches: 1 / 18
# [Epoch 6 | Batch 10] Total: 2.8285 | Coord: 74.5576 | Obj: 16.9528 | NoObj: 23.2604 | Class: 66.2512
# matches: 1 / 17
# [Epoch 6 | Batch 11] Total: 2.3212 | Coord: 51.9633 | Obj: 13.3149 | NoObj: 23.2954 | Class: 59.9867
# matches: 1 / 13
# [Epoch 6 | Batch 12] Total: 3.0823 | Coord: 83.9367 | Obj: 16.8742 | NoObj: 23.2429 | Class: 73.2169
# matches: 2 / 13
# [Epoch 6 | Batch 13] Total: 3.0333 | Coord: 80.7923 | Obj: 17.7514 | NoObj: 23.2379 | Class: 72.3499
# matches: 0 / 15
# [Epoch 6 | Batch 14] Total: 2.7805 | Coord: 71.1364 | Obj: 15.5100 | NoObj: 23.2554 | Class: 68.0509
# matches: 4 / 11
# [Epoch 6 | Batch 15] Total: 3.0853 | Coord: 76.6768 | Obj: 17.9113 | NoObj: 23.2204 | Class: 79.6489
# matches: 5 / 16
# [Epoch 6 | Batch 16] Total: 3.1502 | Coord: 80.6166 | Obj: 17.5140 | NoObj: 23.2029 | Class: 80.2812
# matches: 3 / 16
# [Epoch 6 | Batch 17] Total: 2.7996 | Coord: 71.8590 | Obj: 15.5702 | NoObj: 23.2579 | Class: 68.4844
# matches: 4 / 11
# [Epoch 6 | Batch 18] Total: 2.5813 | Coord: 65.2074 | Obj: 13.9728 | NoObj: 23.2729 | Class: 62.7519
# matches: 2 / 15
# [Epoch 6 | Batch 19] Total: 3.0479 | Coord: 79.0098 | Obj: 18.2652 | NoObj: 23.2429 | Class: 74.5502
# matches: 2 / 20
# [Epoch 6 | Batch 20] Total: 2.4010 | Coord: 60.7252 | Obj: 13.2440 | NoObj: 23.3054 | Class: 56.3872
# matches: 4 / 17
# [Epoch 6 | Batch 21] Total: 2.6230 | Coord: 64.3776 | Obj: 15.5694 | NoObj: 23.2704 | Class: 64.6518
# matches: 5 / 14
# [Epoch 6 | Batch 22] Total: 3.2052 | Coord: 81.7446 | Obj: 18.9270 | NoObj: 23.2104 | Class: 81.2483
# matches: 0 / 15
# [Epoch 6 | Batch 23] Total: 2.5713 | Coord: 64.4289 | Obj: 15.1116 | NoObj: 23.2729 | Class: 61.7520
# matches: 1 / 16
# [Epoch 6 | Batch 24] Total: 3.0379 | Coord: 79.9503 | Obj: 15.5291 | NoObj: 23.2304 | Class: 75.7161
# Validating...
# matches: 1 / 15
# matches: 2 / 16
# matches: 2 / 15
# matches: 1 / 11
# matches: 3 / 16
# matches: 3 / 13
# matches: 2 / 12
# Training Loss: 2.892138090133667
# Validation Loss: 2.848639965057373
# Validation loss has decreased from 4.213899688720703 to 2.848639965057373
# Saving model ...
#
#
# Epoch 7/10 - IOU threshold: 0.065
# Training...
# matches: 0 / 17
# [Epoch 7 | Batch 0] Total: 1.6306 | Coord: 30.9412 | Obj: 8.2096 | NoObj: 23.3504 | Class: 41.8566
# matches: 1 / 15
# [Epoch 7 | Batch 1] Total: 1.6338 | Coord: 30.6967 | Obj: 7.9908 | NoObj: 23.3504 | Class: 42.5232
# matches: 1 / 13
# [Epoch 7 | Batch 2] Total: 1.6758 | Coord: 29.5775 | Obj: 7.4702 | NoObj: 23.3504 | Class: 46.8566
# matches: 2 / 13
# [Epoch 7 | Batch 3] Total: 1.6866 | Coord: 32.3167 | Obj: 8.3148 | NoObj: 23.3529 | Class: 43.9567
# matches: 7 / 16
# [Epoch 7 | Batch 4] Total: 2.0008 | Coord: 38.6095 | Obj: 10.1076 | NoObj: 23.3129 | Class: 56.0210
# matches: 1 / 18
# [Epoch 7 | Batch 5] Total: 1.4582 | Coord: 22.6623 | Obj: 6.6353 | NoObj: 23.3704 | Class: 40.6578
# matches: 1 / 15
# [Epoch 7 | Batch 6] Total: 1.6932 | Coord: 35.5886 | Obj: 8.2614 | NoObj: 23.3579 | Class: 41.1570
# matches: 0 / 14
# [Epoch 7 | Batch 7] Total: 1.4446 | Coord: 24.8065 | Obj: 6.7504 | NoObj: 23.3754 | Class: 37.5247
# matches: 0 / 16
# [Epoch 7 | Batch 8] Total: 1.6270 | Coord: 29.6407 | Obj: 7.8434 | NoObj: 23.3529 | Class: 43.2901
# matches: 2 / 17
# [Epoch 7 | Batch 9] Total: 2.0643 | Coord: 39.2131 | Obj: 9.9775 | NoObj: 23.3029 | Class: 59.6204
# matches: 1 / 13
# [Epoch 7 | Batch 10] Total: 1.6355 | Coord: 29.3075 | Obj: 7.7472 | NoObj: 23.3604 | Class: 44.2572
# matches: 1 / 18
# [Epoch 7 | Batch 11] Total: 1.5192 | Coord: 28.0644 | Obj: 7.8004 | NoObj: 23.3704 | Class: 37.9911
# matches: 1 / 20
# [Epoch 7 | Batch 12] Total: 1.6750 | Coord: 34.4318 | Obj: 8.5893 | NoObj: 23.3579 | Class: 40.8237
# matches: 1 / 13
# [Epoch 7 | Batch 13] Total: 1.3596 | Coord: 22.4082 | Obj: 6.2726 | NoObj: 23.3779 | Class: 34.9582
# matches: 3 / 12
# [Epoch 7 | Batch 14] Total: 1.7305 | Coord: 34.0650 | Obj: 8.5027 | NoObj: 23.3579 | Class: 44.8237
# matches: 2 / 20
# [Epoch 7 | Batch 15] Total: 1.6264 | Coord: 28.0736 | Obj: 8.2422 | NoObj: 23.3479 | Class: 44.4231
# matches: 1 / 12
# [Epoch 7 | Batch 16] Total: 1.8386 | Coord: 36.0893 | Obj: 9.1938 | NoObj: 23.3304 | Class: 49.0554
# matches: 2 / 15
# [Epoch 7 | Batch 17] Total: 1.8262 | Coord: 35.7115 | Obj: 9.1144 | NoObj: 23.3304 | Class: 48.7221
# matches: 1 / 15
# [Epoch 7 | Batch 18] Total: 1.5447 | Coord: 28.6678 | Obj: 8.4705 | NoObj: 23.3629 | Class: 38.3573
# matches: 1 / 12
# [Epoch 7 | Batch 19] Total: 1.5100 | Coord: 27.8255 | Obj: 7.2459 | NoObj: 23.3754 | Class: 38.1914
# matches: 0 / 21
# [Epoch 7 | Batch 20] Total: 1.6469 | Coord: 29.2011 | Obj: 7.9656 | NoObj: 23.3429 | Class: 44.8895
# matches: 5 / 18
# [Epoch 7 | Batch 21] Total: 2.0015 | Coord: 37.2941 | Obj: 10.8505 | NoObj: 23.2954 | Class: 56.6533
# matches: 2 / 12
# [Epoch 7 | Batch 22] Total: 1.7086 | Coord: 30.6372 | Obj: 8.5821 | NoObj: 23.3404 | Class: 46.7893
# matches: 1 / 13
# [Epoch 7 | Batch 23] Total: 1.8059 | Coord: 32.4538 | Obj: 9.0749 | NoObj: 23.3304 | Class: 50.7221
# matches: 6 / 16
# [Epoch 7 | Batch 24] Total: 1.5750 | Coord: 28.6300 | Obj: 7.5247 | NoObj: 23.3529 | Class: 41.2901
# Validating...
# matches: 1 / 15
# matches: 0 / 13
# matches: 0 / 12
# matches: 0 / 15
# matches: 0 / 16
# matches: 0 / 16
# matches: 0 / 12
# Training Loss: 1.6767274141311646
# Validation Loss: 1.809135341644287
# Validation loss has decreased from 2.848639965057373 to 1.809135341644287
# Saving model ...
#
#
# Epoch 8/10 - IOU threshold: 0.120
# Training...
# matches: 1 / 21
# [Epoch 8 | Batch 0] Total: 1.1092 | Coord: 14.6979 | Obj: 4.1563 | NoObj: 23.4054 | Class: 28.7265
# matches: 0 / 17
# [Epoch 8 | Batch 1] Total: 0.9278 | Coord: 12.8259 | Obj: 3.1930 | NoObj: 23.4354 | Class: 19.9283
# matches: 1 / 15
# [Epoch 8 | Batch 2] Total: 0.9189 | Coord: 10.5427 | Obj: 2.6717 | NoObj: 23.4329 | Class: 22.1615
# matches: 0 / 17
# [Epoch 8 | Batch 3] Total: 0.9484 | Coord: 8.8553 | Obj: 2.8882 | NoObj: 23.4254 | Class: 25.5277
# matches: 0 / 15
# [Epoch 8 | Batch 4] Total: 0.9626 | Coord: 11.1969 | Obj: 2.8928 | NoObj: 23.4229 | Class: 24.0942
# matches: 0 / 16
# [Epoch 8 | Batch 5] Total: 1.0025 | Coord: 12.9333 | Obj: 3.3736 | NoObj: 23.4229 | Class: 24.4276
# matches: 1 / 15
# [Epoch 8 | Batch 6] Total: 0.8810 | Coord: 9.0719 | Obj: 2.2836 | NoObj: 23.4354 | Class: 21.5950
# matches: 0 / 20
# [Epoch 8 | Batch 7] Total: 0.8854 | Coord: 10.2825 | Obj: 2.9194 | NoObj: 23.4379 | Class: 20.0285
# matches: 0 / 12
# [Epoch 8 | Batch 8] Total: 0.8244 | Coord: 8.0778 | Obj: 2.3453 | NoObj: 23.4429 | Class: 18.8954
# matches: 0 / 10
# [Epoch 8 | Batch 9] Total: 0.9796 | Coord: 12.6795 | Obj: 3.0617 | NoObj: 23.4254 | Class: 23.5277
# matches: 0 / 16
# [Epoch 8 | Batch 10] Total: 0.9535 | Coord: 9.2318 | Obj: 2.9411 | NoObj: 23.4229 | Class: 25.4276
# matches: 0 / 12
# [Epoch 8 | Batch 11] Total: 0.9391 | Coord: 8.6281 | Obj: 2.2900 | NoObj: 23.4229 | Class: 25.7609
# matches: 1 / 18
# [Epoch 8 | Batch 12] Total: 1.0153 | Coord: 12.3493 | Obj: 3.6746 | NoObj: 23.4254 | Class: 25.5277
# matches: 0 / 11
# [Epoch 8 | Batch 13] Total: 1.0755 | Coord: 13.6269 | Obj: 3.9724 | NoObj: 23.4079 | Class: 27.8267
# matches: 0 / 11
# [Epoch 8 | Batch 14] Total: 1.1929 | Coord: 16.3844 | Obj: 4.5721 | NoObj: 23.3954 | Class: 31.9926
# matches: 2 / 16
# [Epoch 8 | Batch 15] Total: 0.9497 | Coord: 11.3142 | Obj: 3.0754 | NoObj: 23.4279 | Class: 22.9612
# matches: 0 / 12
# [Epoch 8 | Batch 16] Total: 0.8476 | Coord: 9.9039 | Obj: 2.3615 | NoObj: 23.4504 | Class: 18.5292
# matches: 2 / 14
# [Epoch 8 | Batch 17] Total: 1.0618 | Coord: 14.1782 | Obj: 3.6986 | NoObj: 23.4204 | Class: 26.6608
# matches: 1 / 16
# [Epoch 8 | Batch 18] Total: 1.1738 | Coord: 15.3527 | Obj: 3.9474 | NoObj: 23.3979 | Class: 32.4261
# matches: 1 / 18
# [Epoch 8 | Batch 19] Total: 1.0610 | Coord: 12.3508 | Obj: 3.6760 | NoObj: 23.4154 | Class: 28.4605
# matches: 1 / 20
# [Epoch 8 | Batch 20] Total: 1.1373 | Coord: 15.7851 | Obj: 4.0016 | NoObj: 23.4104 | Class: 29.5935
# matches: 0 / 16
# [Epoch 8 | Batch 21] Total: 0.9337 | Coord: 9.0975 | Obj: 2.9361 | NoObj: 23.4279 | Class: 24.2945
# matches: 1 / 18
# [Epoch 8 | Batch 22] Total: 1.2166 | Coord: 12.9551 | Obj: 4.1616 | NoObj: 23.3879 | Class: 37.3588
# matches: 0 / 13
# [Epoch 8 | Batch 23] Total: 0.9397 | Coord: 9.9248 | Obj: 2.7243 | NoObj: 23.4304 | Class: 24.0613
# matches: 0 / 14
# [Epoch 8 | Batch 24] Total: 0.8430 | Coord: 10.9486 | Obj: 2.1282 | NoObj: 23.4479 | Class: 17.4290
# Validating...
# matches: 3 / 16
# matches: 0 / 12
# matches: 1 / 13
# matches: 1 / 16
# matches: 1 / 13
# matches: 0 / 13
# matches: 2 / 12
# Training Loss: 0.9912072825431824
# Validation Loss: 1.0276022911071778
# Validation loss has decreased from 1.809135341644287 to 1.0276022911071778
# Saving model ...
#
#
# Epoch 9/10 - IOU threshold: 0.205
# Training...
# matches: 0 / 16
# [Epoch 9 | Batch 0] Total: 0.5666 | Coord: 2.0951 | Obj: 0.2916 | NoObj: 23.4804 | Class: 10.3976
# matches: 1 / 18
# [Epoch 9 | Batch 1] Total: 0.5807 | Coord: 2.7832 | Obj: 0.5046 | NoObj: 23.4804 | Class: 10.3976
# matches: 1 / 16
# [Epoch 9 | Batch 2] Total: 0.6791 | Coord: 4.6587 | Obj: 0.9037 | NoObj: 23.4729 | Class: 14.4305
# matches: 0 / 12
# [Epoch 9 | Batch 3] Total: 0.5896 | Coord: 2.4562 | Obj: 0.8380 | NoObj: 23.4779 | Class: 10.9642
# matches: 0 / 13
# [Epoch 9 | Batch 4] Total: 0.6463 | Coord: 4.2108 | Obj: 0.7884 | NoObj: 23.4679 | Class: 12.8969
# matches: 0 / 21
# [Epoch 9 | Batch 5] Total: 0.5735 | Coord: 2.5027 | Obj: 0.5515 | NoObj: 23.4829 | Class: 10.1644
# matches: 1 / 14
# [Epoch 9 | Batch 6] Total: 0.6150 | Coord: 3.6624 | Obj: 0.6913 | NoObj: 23.4754 | Class: 11.5307
# matches: 0 / 13
# [Epoch 9 | Batch 7] Total: 0.5987 | Coord: 3.5253 | Obj: 0.6801 | NoObj: 23.4779 | Class: 10.6308
# matches: 0 / 12
# [Epoch 9 | Batch 8] Total: 0.7715 | Coord: 6.2805 | Obj: 0.8083 | NoObj: 23.4579 | Class: 18.8296
# matches: 0 / 18
# [Epoch 9 | Batch 9] Total: 0.6006 | Coord: 3.1511 | Obj: 0.8478 | NoObj: 23.4779 | Class: 10.9642
# matches: 0 / 16
# [Epoch 9 | Batch 10] Total: 0.6138 | Coord: 3.4012 | Obj: 0.8749 | NoObj: 23.4754 | Class: 11.5307
# matches: 0 / 16
# [Epoch 9 | Batch 11] Total: 0.5343 | Coord: 1.8788 | Obj: 0.5651 | NoObj: 23.4854 | Class: 8.2646
# matches: 0 / 14
# [Epoch 9 | Batch 12] Total: 0.5912 | Coord: 3.1010 | Obj: 0.9633 | NoObj: 23.4779 | Class: 10.2975
# matches: 0 / 17
# [Epoch 9 | Batch 13] Total: 0.6605 | Coord: 4.1634 | Obj: 0.8482 | NoObj: 23.4654 | Class: 13.7967
# matches: 0 / 20
# [Epoch 9 | Batch 14] Total: 0.7365 | Coord: 4.5904 | Obj: 1.0266 | NoObj: 23.4554 | Class: 18.0628
# matches: 0 / 16
# [Epoch 9 | Batch 15] Total: 0.7161 | Coord: 3.5955 | Obj: 0.8442 | NoObj: 23.4604 | Class: 17.9298
# matches: 0 / 16
# [Epoch 9 | Batch 16] Total: 0.6768 | Coord: 3.7710 | Obj: 0.8213 | NoObj: 23.4604 | Class: 15.2631
# matches: 0 / 15
# [Epoch 9 | Batch 17] Total: 0.6114 | Coord: 3.3635 | Obj: 0.4291 | NoObj: 23.4754 | Class: 11.8640
# matches: 0 / 20
# [Epoch 9 | Batch 18] Total: 0.5267 | Coord: 2.8277 | Obj: 0.5936 | NoObj: 23.4904 | Class: 6.7982
# matches: 0 / 14
# [Epoch 9 | Batch 19] Total: 0.5442 | Coord: 1.8259 | Obj: 0.4815 | NoObj: 23.4879 | Class: 9.0314
# matches: 1 / 18
# [Epoch 9 | Batch 20] Total: 0.6443 | Coord: 4.5646 | Obj: 0.8714 | NoObj: 23.4704 | Class: 12.3304
# matches: 0 / 11
# [Epoch 9 | Batch 21] Total: 0.6025 | Coord: 2.5893 | Obj: 0.6313 | NoObj: 23.4754 | Class: 11.8640
# matches: 0 / 15
# [Epoch 9 | Batch 22] Total: 0.5291 | Coord: 2.3473 | Obj: 0.6606 | NoObj: 23.4879 | Class: 7.3647
# matches: 0 / 15
# [Epoch 9 | Batch 23] Total: 0.5579 | Coord: 3.0172 | Obj: 0.6059 | NoObj: 23.4854 | Class: 8.5979
# matches: 0 / 11
# [Epoch 9 | Batch 24] Total: 0.7220 | Coord: 5.6598 | Obj: 0.9303 | NoObj: 23.4579 | Class: 16.1630
# Validating...
# matches: 0 / 16
# matches: 0 / 14
# matches: 0 / 12
# matches: 0 / 15
# matches: 0 / 11
# matches: 1 / 16
# matches: 2 / 9
# Training Loss: 0.6195582389831543
# Validation Loss: 0.6588752317428589
# Validation loss has decreased from 1.0276022911071778 to 0.6588752317428589
# Saving model ...
#
#
# Epoch 10/10 - IOU threshold: 0.328
# Training...
# matches: 0 / 21
# [Epoch 10 | Batch 0] Total: 0.4771 | Coord: 1.6566 | Obj: 0.0739 | NoObj: 23.5029 | Class: 5.2990
# matches: 0 / 15
# [Epoch 10 | Batch 1] Total: 0.4780 | Coord: 1.3248 | Obj: 0.1079 | NoObj: 23.4954 | Class: 5.6652
# matches: 0 / 17
# [Epoch 10 | Batch 2] Total: 0.4394 | Coord: 1.0583 | Obj: 0.0558 | NoObj: 23.5079 | Class: 3.4993
# matches: 0 / 16
# [Epoch 10 | Batch 3] Total: 0.4533 | Coord: 1.3437 | Obj: 0.0967 | NoObj: 23.5054 | Class: 4.0658
# matches: 1 / 14
# [Epoch 10 | Batch 4] Total: 0.4982 | Coord: 1.1233 | Obj: 0.0401 | NoObj: 23.4929 | Class: 7.2317
# matches: 0 / 13
# [Epoch 10 | Batch 5] Total: 0.4496 | Coord: 0.9010 | Obj: 0.0751 | NoObj: 23.5029 | Class: 4.2990
# matches: 0 / 11
# [Epoch 10 | Batch 6] Total: 0.4558 | Coord: 0.5893 | Obj: 0.1122 | NoObj: 23.5029 | Class: 4.9656
# matches: 0 / 12
# [Epoch 10 | Batch 7] Total: 0.4364 | Coord: 0.2797 | Obj: 0.0782 | NoObj: 23.5054 | Class: 4.0658
# matches: 0 / 10
# [Epoch 10 | Batch 8] Total: 0.4845 | Coord: 1.5805 | Obj: 0.1646 | NoObj: 23.4979 | Class: 5.7653
# matches: 1 / 14
# [Epoch 10 | Batch 9] Total: 0.4860 | Coord: 1.3495 | Obj: 0.1585 | NoObj: 23.4979 | Class: 6.0987
# matches: 0 / 18
# [Epoch 10 | Batch 10] Total: 0.4616 | Coord: 0.7042 | Obj: 0.1363 | NoObj: 23.5004 | Class: 5.1988
# matches: 0 / 17
# [Epoch 10 | Batch 11] Total: 0.5001 | Coord: 1.1900 | Obj: 0.0946 | NoObj: 23.4929 | Class: 7.2317
# matches: 0 / 17
# [Epoch 10 | Batch 12] Total: 0.4914 | Coord: 1.1370 | Obj: 0.0487 | NoObj: 23.4979 | Class: 6.7653
# matches: 0 / 20
# [Epoch 10 | Batch 13] Total: 0.4409 | Coord: 0.6653 | Obj: 0.0862 | NoObj: 23.5029 | Class: 3.9656
# matches: 0 / 16
# [Epoch 10 | Batch 14] Total: 0.5049 | Coord: 1.2221 | Obj: 0.1377 | NoObj: 23.4904 | Class: 7.4649
# matches: 0 / 18
# [Epoch 10 | Batch 15] Total: 0.4812 | Coord: 1.0409 | Obj: 0.0547 | NoObj: 23.5004 | Class: 6.1988
# matches: 0 / 10
# [Epoch 10 | Batch 16] Total: 0.4618 | Coord: 1.0818 | Obj: 0.1076 | NoObj: 23.5004 | Class: 4.8655
# matches: 0 / 15
# [Epoch 10 | Batch 17] Total: 0.5298 | Coord: 1.7895 | Obj: 0.1600 | NoObj: 23.4904 | Class: 8.4649
# matches: 0 / 16
# [Epoch 10 | Batch 18] Total: 0.4099 | Coord: 0.4047 | Obj: 0.0547 | NoObj: 23.5104 | Class: 2.2661
# matches: 0 / 14
# [Epoch 10 | Batch 19] Total: 0.4154 | Coord: 0.4136 | Obj: 0.0610 | NoObj: 23.5104 | Class: 2.5994
# matches: 1 / 16
# [Epoch 10 | Batch 20] Total: 0.5177 | Coord: 1.2885 | Obj: 0.2229 | NoObj: 23.4904 | Class: 8.1316
# matches: 0 / 20
# [Epoch 10 | Batch 21] Total: 0.4560 | Coord: 0.9781 | Obj: 0.0721 | NoObj: 23.5029 | Class: 4.6323
# matches: 1 / 11
# [Epoch 10 | Batch 22] Total: 0.4310 | Coord: 0.6286 | Obj: 0.0540 | NoObj: 23.5054 | Class: 3.3991
# matches: 0 / 18
# [Epoch 10 | Batch 23] Total: 0.4226 | Coord: 0.6422 | Obj: 0.0634 | NoObj: 23.5079 | Class: 2.8326
# matches: 0 / 16
# [Epoch 10 | Batch 24] Total: 0.4121 | Coord: 0.4444 | Obj: 0.0527 | NoObj: 23.5129 | Class: 2.3662
# Validating...
# matches: 1 / 15
# matches: 0 / 13
# matches: 0 / 16
# matches: 0 / 13
# matches: 1 / 11
# matches: 0 / 16
# matches: 0 / 10
# Training Loss: 0.4637891721725464
# Validation Loss: 0.45755335569381717
# Validation loss has decreased from 0.6588752317428589 to 0.45755335569381717
# Saving model ...
#
#
# Total Time for Training: 0:49:19

# %% [markdown]
# ---
# ## Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_trained.pt', weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ---
# ## Test the Trained Network

# %%
# track test loss
test_loss = 0.0
class_correct = [0. for _ in range(NUM_CLASSES)]
class_total = [0. for _ in range(NUM_CLASSES)]

# TODO: adjust TEST_CONFIDENCE_THRESHOLD and TEST_IOU_THRESHOLD
TEST_CONFIDENCE_THRESHOLD = CONFIDENCE_THRESHOLD
TEST_IOU_THRESHOLD = 0.328
print("Testing with confidence threshold:", TEST_CONFIDENCE_THRESHOLD, "and IOU threshold:", TEST_IOU_THRESHOLD)

model.eval()
for batch_idx, (data, target) in enumerate(test_loader):
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()

    with torch.no_grad():
        output = model(data)
        # calculate the batch loss
        loss, coord_loss, obj_loss, noobj_loss, class_loss = criterion(output, target, anchors, TEST_CONFIDENCE_THRESHOLD, TEST_IOU_THRESHOLD)
        test_loss += loss.item() * data.size(0)

    batch_size = data.size(0)

    for b in range(batch_size):
        preds = output[b]       # shape: [batch_size, S, S, num_anchors, 5 + num_classes]
        labels = target[b]      # shape: [M, 5 + num_classes]

        labels = labels[labels[:, 0] != -1]  # remove padding
        preds = preds.view(-1, preds.shape[-1])
        # print("Sample pred after reshape:", preds[0])

        for gt in labels:
            gt_class = int(torch.argmax(gt[5:]).item())
            best_iou = 0
            best_pred_class = None

            assert preds.shape == (GRID_SIZE * GRID_SIZE * NUMBER_ANCHORS, 5 + NUM_CLASSES)
            for pred in preds:
                iou = calculate_iou(pred[:4], gt[1:5])
                if iou > best_iou:
                    best_iou = iou
                    best_pred_class = torch.argmax(pred[5:]).item()

            class_total[gt_class] += 1
            if best_iou > TEST_IOU_THRESHOLD:
                if best_pred_class == gt_class:
                    class_correct[gt_class] += 1

# average test loss
test_loss = test_loss / len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(NUM_CLASSES):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            CLASSES[i], 100 * class_correct[i] / class_total[i],
            class_correct[i], class_total[i]))
    else:
        print('Test Accuracy of %5s: N/A (no ground truth samples)' % (CLASSES[i]))

if sum(class_total) > 0:
    print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
        100. * sum(class_correct) / sum(class_total),
        sum(class_correct), sum(class_total)))
else:
    print('\nTest Accuracy (Overall): N/A (no valid ground truth boxes in test set)')
# Out:
# Testing with confidence threshold: 0.1 and IOU threshold: 0.328
# matches: 0 / 13
# matches: 0 / 13
# matches: 0 / 18
# matches: 0 / 12
# matches: 0 / 15
# matches: 0 / 12
# matches: 0 / 15
# matches: 0 / 17
# matches: 0 / 14
# matches: 0 / 13
# matches: 0 / 14
# matches: 0 / 28
# matches: 0 / 13
# matches: 0 / 16
# matches: 1 / 12
# matches: 0 / 19
# matches: 1 / 16
# matches: 0 / 27
# matches: 0 / 10
# matches: 0 / 13
# matches: 0 / 12
# matches: 0 / 14
# matches: 0 / 14
# matches: 1 / 16
# matches: 0 / 14
# matches: 0 / 18
# matches: 0 / 14
# matches: 0 / 12
# Test Loss: 0.480549
#
# Test Accuracy of  head:  1% (29/1803)
# Test Accuracy of helmet:  4% (224/4863)
# Test Accuracy of person: 15% (22/142)
#
# Test Accuracy (Overall):  4% (275/6808)

# %% [markdown]
# ## Visualize Sample Test Results

# %% [markdown]
# ### Non-Maximum Suppression Function
#
# This is to remove redundant overlapping boxes that the predicted the same object

# %%
import torchvision.ops as ops

def apply_nms(predictions, iou_threshold=TEST_IOU_THRESHOLD, conf_threshold=TEST_CONFIDENCE_THRESHOLD):
    boxes = []
    scores = []
    class_ids = []

    for pred in predictions:
        conf = pred[4].item()
        if conf < conf_threshold:
            continue

        class_score, class_id = torch.max(pred[5:], dim=0)
        total_score = conf * class_score.item()

        if total_score < conf_threshold:
            continue

        x, y, w, h = pred[0:4]
        x1 = x - w / 2
        y1 = y - h / 2
        x2 = x + w / 2
        y2 = y + h / 2

        boxes.append([x1, y1, x2, y2])
        scores.append(total_score)
        class_ids.append(class_id.item())

    if not boxes:
        return torch.empty((0, 5 + predictions.shape[1] - 5))

    boxes = torch.tensor(boxes)
    scores = torch.tensor(scores)

    keep = ops.nms(boxes, scores, iou_threshold)
    filtered_preds = []

    for idx in keep:
        pred = predictions[idx].clone()
        pred[4] = scores[idx]  # overwrite with actual used score (conf class prob)
        filtered_preds.append(pred)
    
    return torch.stack(filtered_preds)

# %% [markdown]
# ### Visualize Outputs

# %%
import matplotlib.pyplot as plt
import random

# Collect all test samples into memory for random access
all_images = []
all_targets = []

for images, targets in test_loader:
    all_images.extend(images)
    all_targets.extend(targets)

# Choose N random indices
N = 4
indices = random.sample(range(len(all_images)), k=N)

fig, axs = plt.subplots(1, N, figsize=(5 * N, 5))
if N == 1:
    axs = [axs]

model.eval()
for i, idx in enumerate(indices):
    image = all_images[idx].unsqueeze(0).to(next(model.parameters()).device)
    target = all_targets[idx].to(image.device)

    with torch.no_grad():
        output = model(image)[0].cpu()

    img = image[0].cpu().permute(1, 2, 0).numpy()
    img = (img - img.min()) / (img.max() - img.min() + 1e-5)
    ax = axs[i]
    ax.imshow(img)
    ax.axis("off")
    ax.set_title(f"Random Sample {idx}")

    # Draw predicted and ground truth boxes
    output = output.view(-1, output.shape[-1])
    output = apply_nms(output, iou_threshold=TEST_IOU_THRESHOLD, conf_threshold=TEST_CONFIDENCE_THRESHOLD)
    draw_bounding_boxes(ax, target.cpu(), img.shape[:2], CLASSES, color="red", is_prediction=False)
    draw_bounding_boxes(ax, output, img.shape[:2], CLASSES, color="lime", is_prediction=True)

plt.tight_layout()
plt.show()
