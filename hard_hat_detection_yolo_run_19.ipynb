# %% [markdown]
# # Safety First - Hard Hat Detection

# %% [markdown]
# ---
# ## Project Proposal
#
# ### Team Member
#
# - Stanley Yang
# - Lennard Vanderspek
#
# ### Description
#
# Workplace safety is very important but often overlooked. Most important way to keep workers
# safe is by wearing a hard hat. This project will utilize Convolution Neural Net and YOLO to help
# detect whether workers are wearing a hard hat or not.
#
# #### Machine Learning Topics Used:
#
# - Convolution Neural Net
# - YOLO
#
# ### Expected Outcome
#
# A trained model that is able to detect whether workers are wearing a hard hat or not by
# implementing YOLO using PyTorch. We are hoping to utilize the model to bring more awareness
# to workplace safety.

# %% [markdown]
# ---
#
# ## Use CUDA if Available

# %%
import torch

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
    print("CUDA is not available.  Training on CPU ...")
else:
    print(f"CUDA is available!  Training on GPU ({torch.cuda.get_device_name(0)}) ...")
# Out:
# CUDA is available!  Training on GPU (NVIDIA GeForce RTX 3070) ...

# %% [markdown]
# ---
# ## Load the Data

# %% [markdown]
# ### Create Custom Dataset Class

# %%
from torch.utils.data import Dataset
import cv2
import torchvision.transforms as transforms
import os
from PIL import Image

# specify the image classes
CLASSES = ['head', 'helmet', 'person']
NUM_CLASSES = len(CLASSES)

def yolo_collate_fn(batch):
    images, labels = zip(*batch)
    images = torch.stack(images, dim=0)
    # Pad labels to the max number of objects in the batch
    max_objs = max(label.shape[0] for label in labels)
    padded_labels = []
    for label in labels:
        pad_size = max_objs - label.shape[0]
        if pad_size > 0:
            # Pad with -1
            padded = torch.nn.functional.pad(label, (0, 0, 0, pad_size), value=-1)
        else:
            padded = label
        padded_labels.append(padded)
    labels = torch.stack(padded_labels, dim=0)
    return images, labels

class custom_dataset(Dataset):
    def __init__(self, image_path, label_path, transform:transforms = None, number_image_to_load=None):
        self.image_path = image_path
        self.label_path = label_path
        self.transform = transform

        if number_image_to_load is None:
            # Load images and labels
            self.images = sorted(os.listdir(image_path))
            self.labels = sorted(os.listdir(label_path))
        else:
            # Load a limited number of images and labels
            self.images = sorted(os.listdir(image_path))[:number_image_to_load]
            self.labels = sorted(os.listdir(label_path))[:number_image_to_load]
    
    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        image_name = self.images[index]
        label_name = self.labels[index]

        # Ensure the label file corresponds to the image file
        if not label_name.startswith(image_name.split('.')[0]):
            raise ValueError(f"Label file {label_name} does not match image file {image_name}")

        # Load the image
        image = cv2.imread(os.path.join(self.image_path, image_name))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image = Image.fromarray(image)
        if self.transform:
            image = self.transform(image)

        # Load the label
        # Example INPUT with format [class_id, x_center, y_center, width, height]
        # 1 0.502 0.6506024096385542 0.032 0.060240963855421686
        #
        # Example converted OUTPUT with format [x_center, y_center, width, height, confidence, class_0, class_1, class_2]
        # 0.502 0.6506024096385542 0.032 0.060240963855421686 1 0.0 1.0 0.0
        labels = []
        with open(os.path.join(self.label_path, label_name), 'r') as f:
            for line in f.readlines():
                parts = line.strip().split()
                if len(parts) != 5:
                    print(f"Skipping invalid label line: {line.strip()}")
                    continue
                class_id = int(parts[0])
                x_center = float(parts[1])
                y_center = float(parts[2])
                width = float(parts[3])
                height = float(parts[4])

                # Confidence = 1.0 for ground truth
                conf = 1.0

                # One-hot encoding for class
                one_hot_class = [0.0] * NUM_CLASSES
                one_hot_class[class_id] = 1.0

                # Final label vector
                labels.append([x_center, y_center, width, height, conf] + one_hot_class)

        return image, torch.tensor(labels, dtype=torch.float32)

# %% [markdown]
# ### Load the Data using Custom Dataset Class

# %%
import numpy as np
from torch.utils.data.sampler import SubsetRandomSampler

# TODO: Need to adjust the default values

# number of subprocesses to use for data loading
num_workers = 0

# how many samples per batch to load
batch_size = 64

# percentage of training set to use as validation
valid_size = 0.2

# number of data to load (None for all)
train_data_to_load = 2000   # at least 2000 for a good training
test_data_to_load = None

# resize the images to this size
# smaller size means faster training
# larger size means better detection on small objects
image_size = (256, 256)

# convert data to a normalized torch.FloatTensor
transform = transforms.Compose(
    [
        transforms.Resize(image_size),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ]
)

# load the data set
train_data = custom_dataset(
    image_path="data-yolo-v7/train/images",
    label_path="data-yolo-v7/train/labels",
    transform=transform,
    number_image_to_load=train_data_to_load,
)
test_data = custom_dataset(
    image_path="data-yolo-v7/test/images",
    label_path="data-yolo-v7/test/labels",
    transform=transform,
    number_image_to_load=test_data_to_load,
)
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=batch_size,
    sampler=train_sampler,
    num_workers=num_workers,
    collate_fn=yolo_collate_fn,
    pin_memory=train_on_gpu,
)
valid_loader = torch.utils.data.DataLoader(
    train_data,
    batch_size=batch_size,
    sampler=valid_sampler,
    num_workers=num_workers,
    collate_fn=yolo_collate_fn,
    pin_memory=train_on_gpu,
)
test_loader = torch.utils.data.DataLoader(
    test_data,
    batch_size=batch_size,
    num_workers=num_workers,
    collate_fn=yolo_collate_fn,
    pin_memory=train_on_gpu,
)

# %% [markdown]
# ### Custom Bounding Box Drawing

# %%
from matplotlib import patches


def draw_bounding_boxes(ax, labels, img_size, class_names, color="lime", is_prediction=True):
    h, w = img_size

    for box in labels:
        # Only skip if ground truth and it's padding
        if not is_prediction and box[0] == -1:
            continue

        x_center, y_center, box_w, box_h = box[:4]

        x = (x_center - box_w / 2) * w
        y = (y_center - box_h / 2) * h
        width = box_w * w
        height = box_h * h

        if box.shape[0] > 5:
            class_id = torch.argmax(box[5:]).item()
        else:
            class_id = int(box[0]) if not is_prediction else 0

        label_text = class_names[class_id] if class_id < len(class_names) else "?"

        if is_prediction and box.shape[0] > 4:
            label_text += f" {box[4].item():.2f}"

        rect = patches.Rectangle(
            (x, y), width, height, linewidth=2, edgecolor=color, facecolor="none"
        )
        ax.add_patch(rect)

        ax.text(
            x,
            max(y - 5, 0),
            label_text,
            color=color,
            backgroundcolor="black",
            fontsize=10,
        )

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# obtain one batch of training images
dataiter = iter(train_loader)

#images, labels = dataiter.next() #python, torchvision version match issue
images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 25))

# display 2 images
for idx in range(2):
    ax = fig.add_subplot(1, 2, idx+1, xticks=[], yticks=[])
    image_np = np.transpose(images[idx], (1, 2, 0))  # shape: (H, W, C)
    image_np = image_np * 0.5 + 0.5  # unnormalize
    ax.imshow(image_np)

    label = labels[idx]
    valid_labels = label[~(label == -1).all(dim=1)]
    draw_bounding_boxes(ax, valid_labels, img_size=(image_np.shape[0], image_np.shape[1]), class_names=CLASSES, is_prediction=False)

    # filter out padding (rows where all values are -1)

    
    valid_labels = label[~(label == -1).all(axis=1)]
    ax.set_title(f'Labels:\n{valid_labels}')

plt.show()

# %% [markdown]
# ### View an Image in More Detail
#
# Showing the normalized red, green, and blue (RGB) color channels as three separate, gray scale intensity images.

# %%
rgb_img = np.squeeze(images[0])
channels = ["red channel", "green channel", "blue channel"]
step = 10  # visualizing in steps of 10 pixels due to large image size

fig = plt.figure(figsize=(36, 36))
for idx in np.arange(rgb_img.shape[0]):
    ax = fig.add_subplot(1, 3, idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap="gray")
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max() / 2.5
    for x in range(0, width, step):
        for y in range(0, height, step):
            val = round(img[x][y], 2) if img[x][y] != 0 else 0
            ax.annotate(
                str(val),
                xy=(y, x),
                horizontalalignment="center",
                verticalalignment="center",
                size=8,
                color="white" if img[x][y] < thresh else "black",
            )

plt.show()

# %% [markdown]
# ---
# ## Define the Network Architecture

# %%
import torch.nn as nn

# TOD: adjust the default values
NUMBER_ANCHORS = 3
GRID_SIZE = 7

class yolo(nn.Module):
    # TODO: adjust the default values
    def __init__(self, num_anchors=NUMBER_ANCHORS, grid_size=GRID_SIZE, NUM_CLASSES=NUM_CLASSES):
        super(yolo, self).__init__()

        self.num_anchors = num_anchors
        self.num_classes = NUM_CLASSES
        self.grid_size = grid_size

        self.convolution_layers = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((self.grid_size, self.grid_size))
        )

        self.detection_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(256 * grid_size * grid_size, grid_size * grid_size * num_anchors * (5 + NUM_CLASSES))
        )

    def forward(self, x):
        features = self.convolution_layers(x)
        predictions = self.detection_layers(features)
        predictions = predictions.view(-1, self.grid_size, self.grid_size, self.num_anchors, 5 + self.num_classes)

        # Clone before applying activations to avoid in-place modification issues during back probgation
        out = predictions.clone()

        out[..., 0:2] = torch.sigmoid(predictions[..., 0:2])                     # x, y
        out[..., 4]   = torch.sigmoid(predictions[..., 4])                       # objectness
        out[..., 2:4] = torch.sigmoid(predictions[..., 2:4])           # w, h
        out[..., 5:]  = torch.softmax(predictions[..., 5:], dim=-1)             # class probs

        return out



# create a complete CNN
model = yolo()
print(model)

# output total number of parameters
print(
    f"Total parameters: {sum(p.numel() for p in model.parameters() if p.requires_grad)}"
)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()
# Out:
# yolo(
#   (convolution_layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(3, 3))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): AdaptiveAvgPool2d(output_size=(7, 7))
#   )
#   (detection_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=12544, out_features=1176, bias=True)
#   )
# )
# Total parameters: 15124632

# %% [markdown]
# ---
# ## Specify Loss Function and Optimizer

# %% [markdown]
# ### Create Custom Loss Function for YOLO
#
# YOLO loss function is defined as following ([reference](https://www.geeksforgeeks.org/computer-vision/yolov3-from-scratch-using-pytorch/)):
#
# ![loss function](./assets/images/yolo_loss_function.png)

# %%
LAMBDA_COORD = 5.0
LAMBDA_OBJ = 1.0
LAMBDA_NOOBJ = 0.01
LAMBDA_CLASS = 1.0

def calculate_iou(pred, target):
    pred_x1 = pred[0] - pred[2] / 2
    pred_y1 = pred[1] - pred[3] / 2
    pred_x2 = pred[0] + pred[2] / 2
    pred_y2 = pred[1] + pred[3] / 2

    target_x1 = target[0] - target[2] / 2
    target_y1 = target[1] - target[3] / 2
    target_x2 = target[0] + target[2] / 2
    target_y2 = target[1] + target[3] / 2

    inter_x1 = torch.max(pred_x1, target_x1)
    inter_y1 = torch.max(pred_y1, target_y1)
    inter_x2 = torch.min(pred_x2, target_x2)
    inter_y2 = torch.min(pred_y2, target_y2)

    inter_area = (inter_x2 - inter_x1).clamp(0) * (inter_y2 - inter_y1).clamp(0)
    pred_area = (pred_x2 - pred_x1) * (pred_y2 - pred_y1)
    target_area = (target_x2 - target_x1) * (target_y2 - target_y1)
    union = pred_area + target_area - inter_area

    return inter_area / (union + 1e-6)

def custom_loss(predictions, targets, anchors, confidence_threshold, iou_threshold,
                lambda_coord=LAMBDA_COORD, lambda_obj=LAMBDA_OBJ,
                lambda_noobj=LAMBDA_NOOBJ, lambda_class=LAMBDA_CLASS):
    batch_size, grid_height, grid_width, num_anchors, pred_len = predictions.shape
    device = predictions.device
    losses = []

    coord_total = 0.0
    obj_total = 0.0
    noobj_total = 0.0
    class_total = 0.0

    one_tensor = torch.tensor(1.0, device=device)
    zero_tensor = torch.tensor(0.0, device=device)

    for i in range(batch_size):
        matched = []
        used_targets = set()
        pred = predictions[i]
        target = targets[i]

        for target_i, target_box in enumerate(target):
            gx, gy = target_box[0], target_box[1]
            # grid_x = int(gx * grid_width)
            # grid_y = int(gy * grid_height)
            grid_x = min(grid_width - 1, max(0, int(gx * grid_width)))
            grid_y = min(grid_height - 1, max(0, int(gy * grid_height)))


            best_iou = 0
            best_anchor = -1

            for anchor_idx in range(num_anchors):
                pred_box = pred[grid_y, grid_x, anchor_idx]

                anchor_w, anchor_h = anchors[anchor_idx]
                px = torch.sigmoid(pred_box[0])
                py = torch.sigmoid(pred_box[1])
                pw = torch.exp(pred_box[2]) * anchor_w
                ph = torch.exp(pred_box[3]) * anchor_h
                pred_box_decoded = torch.tensor([px, py, pw, ph])

                iou = calculate_iou(pred_box_decoded, target_box[:4])
                if iou > best_iou:
                    best_iou = iou
                    best_anchor = anchor_idx

            # best_anchor_idx = best_anchor
            if target_i not in used_targets and best_iou > iou_threshold and best_anchor != -1:
                matched.append((grid_y, grid_x, best_anchor, target_i))
                used_targets.add(target_i)

            # if best_iou > iou_threshold and best_anchor != -1:
            #     matched.append((grid_y, grid_x, best_anchor, target_i))
            #     used_targets.add(target_i)

        for gy in range(grid_height):
            for gx in range(grid_width):
                for a in range(num_anchors):
                    pred_box = pred[gy, gx, a]
                    pred_conf = torch.sigmoid(pred_box[4])

                    match = next(((my, mx, ma, ti) for (my, mx, ma, ti) in matched if my == gy and mx == gx and ma == a), None)

                    if match:
                        _, _, _, target_i = match
                        target_box = target[target_i]

                        anchor_w, anchor_h = anchors[a]
                        px = torch.sigmoid(pred_box[0])
                        py = torch.sigmoid(pred_box[1])
                        pw = (torch.exp(pred_box[2]) * anchor_w).clamp(min=1e-6)
                        ph = (torch.exp(pred_box[3]) * anchor_h).clamp(min=1e-6)
                        pred_box_decoded = torch.stack([px, py, pw, ph])

                        box_loss = (
                            torch.nn.functional.mse_loss(px, target_box[0]) +
                            torch.nn.functional.mse_loss(py, target_box[1]) +
                            torch.nn.functional.mse_loss(torch.sqrt(pw + 1e-6), torch.sqrt(target_box[2] + 1e-6)) +
                            torch.nn.functional.mse_loss(torch.sqrt(ph + 1e-6), torch.sqrt(target_box[3] + 1e-6))
                        )

                        iou_score = calculate_iou(pred_box_decoded, target_box[:4])
                        obj_loss = torch.nn.functional.mse_loss(pred_conf, iou_score.detach())

                        class_loss = torch.nn.functional.binary_cross_entropy(torch.sigmoid(pred_box[5:]), target_box[5:])

                        coord_total += lambda_coord * box_loss
                        obj_total += lambda_obj * obj_loss
                        class_total += lambda_class * class_loss

                        losses.append(lambda_coord * box_loss + lambda_obj * obj_loss + lambda_class * class_loss)
                    else:
                        noobj_loss = torch.nn.functional.mse_loss(pred_conf, zero_tensor)
                        noobj_total += lambda_noobj * noobj_loss
                        losses.append(lambda_noobj * noobj_loss)

    total_loss = torch.stack(losses).sum() / batch_size if losses else torch.tensor(0.0, device=device)
    print(f"matches: {len(matched)} / {len(target)}")

    if torch.is_grad_enabled():
        assert total_loss.requires_grad, "Loss does not require grad!"

    return total_loss, coord_total, obj_total, noobj_total, class_total

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ExponentialLR

# specify loss function (categorical cross-entropy)
criterion = custom_loss

# specify optimizer
# TODO: adjust the learning rate
# smaller lr means it requires more epochs to improve
# larger lr means it may overshoot and become unstable
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ---
# ## Train the Network

# %% [markdown]
# ### Variables Needed for Training

# %%
valid_loss_min = np.inf  # track change in validation loss
total_epochs_run = 0

# TODO: Need to adjust base on the anchor size
anchors = torch.tensor([
    [0.10, 0.15],  # Small object
    [0.20, 0.30],  # Medium object
    [0.40, 0.50]   # Larger object
], dtype=torch.float32)

# %% [markdown]
# ### Can Run the Following Section as Many time as wanted

# %%
import time
from datetime import timedelta

start_time = time.time()

# TODO: update the following variable
n_epochs = 10   # number of epochs to run for this iteration
CONFIDENCE_THRESHOLD = 0.01

IOU_THRESHOLD = NEW_IOU_THRESHOLD = IOU_START = 0
IOU_END = 0.5
IOU_RAMPUP_EPOCHS = 10

# load the model if this is a continuation of training
if total_epochs_run > 0:
    print(f"Continuing training from epoch {total_epochs_run + 1}")
    model.load_state_dict(torch.load("model_trained.pt", weights_only=True))

for epoch in range(1, n_epochs + 1):
    IOU_THRESHOLD = NEW_IOU_THRESHOLD
    print(f"Epoch {total_epochs_run + epoch}/{total_epochs_run + n_epochs} - IOU threshold: {IOU_THRESHOLD:.6f}")

    # keep track of training and validation loss
    train_loss = 0.0
    valid_loss = 0.0

    ###################
    # train the model #
    ###################
    print("Training...")
    model.train()
    for batch_idx, (images, targets) in enumerate(train_loader):
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            images, targets = images.cuda(), targets.cuda()

        # clear the gradients of all optimized variables
        optimizer.zero_grad()

        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(images)

        # calculate the batch loss
        loss, coord_loss, obj_loss, noobj_loss, class_loss = criterion(output, targets, anchors, CONFIDENCE_THRESHOLD, IOU_THRESHOLD)
        print(f"[Epoch {epoch} | Batch {batch_idx}] Total: {loss.item():.4f} | Coord: {coord_loss:.4f} | Obj: {obj_loss:.4f} | NoObj: {noobj_loss:.4f} | Class: {class_loss:.4f}")

        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward(retain_graph=True)

        # clip the gradients to avoid exploding gradients
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=2.0)

        # perform a single optimization step (parameter update)
        optimizer.step()

        # update training loss
        train_loss += loss.item() * images.size(0)

    ######################
    # validate the model #
    ######################
    print("Validating...")
    model.eval()
    for batch_idx, (images, targets) in enumerate(valid_loader):
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            images, targets = images.cuda(), targets.cuda()

        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(images)

        # calculate the batch loss
        loss, coord_loss, obj_loss, noobj_loss, class_loss = criterion(output, targets, anchors, CONFIDENCE_THRESHOLD, IOU_THRESHOLD)

        # update average validation loss
        valid_loss += loss.item() * images.size(0)

    # calculate average losses
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(valid_loader.sampler)

    # print training/validation statistics
    print(f"Training Loss: {train_loss}")
    print(f"Validation Loss: {valid_loss}")

    # save model if validation loss has decreased
    if valid_loss > 0 and valid_loss <= valid_loss_min:
        print(f"Validation loss has decreased from {valid_loss_min} to {valid_loss}")
        print("Saving model ...")
        torch.save(model.state_dict(), "model_trained.pt")
        valid_loss_min = valid_loss
    
    # update IOU if this is not the first epoch
    if epoch <= IOU_RAMPUP_EPOCHS:
        ramp_factor = epoch / IOU_RAMPUP_EPOCHS
        NEW_IOU_THRESHOLD = IOU_START + (IOU_END - IOU_START) * (ramp_factor ** 4)
        NEW_IOU_THRESHOLD = min(NEW_IOU_THRESHOLD, IOU_END)

    print("\n")

total_epochs_run += n_epochs

end_time = time.time()
total_duration = end_time - start_time
print(f"Total Time for Training: {str(timedelta(seconds=int(total_duration)))}")
# Out:
# Epoch 1/10 - IOU threshold: 0.000
# Training...
# matches: 6 / 11
# [Epoch 1 | Batch 0] Total: 11.1456 | Coord: 484.2463 | Obj: 61.2197 | NoObj: 35.7677 | Class: 132.0824
# matches: 2 / 18
# [Epoch 1 | Batch 1] Total: 5.4822 | Coord: 186.0967 | Obj: 29.7233 | NoObj: 23.3398 | Class: 111.7028
# matches: 3 / 13
# [Epoch 1 | Batch 2] Total: 5.8751 | Coord: 207.8531 | Obj: 33.3401 | NoObj: 23.0814 | Class: 111.7299
# matches: 1 / 17
# [Epoch 1 | Batch 3] Total: 5.1252 | Coord: 166.5848 | Obj: 28.5389 | NoObj: 23.1128 | Class: 109.7774
# matches: 1 / 18
# [Epoch 1 | Batch 4] Total: 4.7878 | Coord: 155.7156 | Obj: 26.7043 | NoObj: 23.1303 | Class: 100.8685
# matches: 1 / 16
# [Epoch 1 | Batch 5] Total: 5.7896 | Coord: 199.0520 | Obj: 32.5560 | NoObj: 23.0778 | Class: 115.8521
# matches: 1 / 9
# [Epoch 1 | Batch 6] Total: 5.1515 | Coord: 178.1280 | Obj: 27.8149 | NoObj: 23.1178 | Class: 100.6329
# matches: 3 / 15
# [Epoch 1 | Batch 7] Total: 5.3633 | Coord: 176.2725 | Obj: 31.1363 | NoObj: 23.0728 | Class: 112.7684
# matches: 3 / 15
# [Epoch 1 | Batch 8] Total: 5.4122 | Coord: 181.9117 | Obj: 30.1550 | NoObj: 23.1128 | Class: 111.2030
# matches: 8 / 15
# [Epoch 1 | Batch 9] Total: 4.4504 | Coord: 141.5107 | Obj: 25.7254 | NoObj: 23.1378 | Class: 94.4525
# matches: 4 / 12
# [Epoch 1 | Batch 10] Total: 4.8556 | Coord: 159.3310 | Obj: 26.1984 | NoObj: 23.1353 | Class: 102.0916
# matches: 5 / 11
# [Epoch 1 | Batch 11] Total: 4.2846 | Coord: 139.8424 | Obj: 23.8281 | NoObj: 23.1703 | Class: 87.3753
# matches: 1 / 15
# [Epoch 1 | Batch 12] Total: 4.8777 | Coord: 161.3943 | Obj: 27.8465 | NoObj: 23.1378 | Class: 99.7972
# matches: 3 / 14
# [Epoch 1 | Batch 13] Total: 4.3354 | Coord: 140.8200 | Obj: 25.1502 | NoObj: 23.1703 | Class: 88.3278
# matches: 2 / 14
# [Epoch 1 | Batch 14] Total: 5.0695 | Coord: 173.2037 | Obj: 28.8815 | NoObj: 23.1378 | Class: 99.2231
# matches: 1 / 17
# [Epoch 1 | Batch 15] Total: 4.9032 | Coord: 161.6471 | Obj: 28.0918 | NoObj: 23.1228 | Class: 100.9415
# matches: 16 / 21
# [Epoch 1 | Batch 16] Total: 6.0064 | Coord: 201.6588 | Obj: 35.6212 | NoObj: 23.0478 | Class: 124.0823
# matches: 1 / 13
# [Epoch 1 | Batch 17] Total: 4.8547 | Coord: 155.6152 | Obj: 27.7576 | NoObj: 23.1178 | Class: 104.2097
# matches: 5 / 10
# [Epoch 1 | Batch 18] Total: 5.1061 | Coord: 163.5753 | Obj: 29.5202 | NoObj: 23.1103 | Class: 110.5847
# matches: 1 / 18
# [Epoch 1 | Batch 19] Total: 6.5047 | Coord: 223.4476 | Obj: 37.6371 | NoObj: 22.9928 | Class: 132.2208
# matches: 1 / 13
# [Epoch 1 | Batch 20] Total: 4.8919 | Coord: 154.9170 | Obj: 27.8148 | NoObj: 23.1103 | Class: 107.2381
# matches: 1 / 13
# [Epoch 1 | Batch 21] Total: 4.7755 | Coord: 159.4880 | Obj: 27.5895 | NoObj: 23.1428 | Class: 95.4107
# matches: 2 / 11
# [Epoch 1 | Batch 22] Total: 4.3600 | Coord: 139.5683 | Obj: 25.1115 | NoObj: 23.1528 | Class: 91.2076
# matches: 5 / 17
# [Epoch 1 | Batch 23] Total: 5.3671 | Coord: 179.2804 | Obj: 31.6800 | NoObj: 23.0903 | Class: 109.4415
# matches: 1 / 20
# [Epoch 1 | Batch 24] Total: 5.2224 | Coord: 176.4625 | Obj: 29.8273 | NoObj: 23.1178 | Class: 104.8267
# Validating...
# matches: 4 / 11
# matches: 1 / 20
# matches: 1 / 13
# matches: 5 / 16
# matches: 3 / 14
# matches: 2 / 16
# matches: 1 / 11
# Training Loss: 5.359901008605957
# Validation Loss: 5.353395614624024
# Validation loss has decreased from inf to 5.353395614624024
# Saving model ...
#
#
# Epoch 2/10 - IOU threshold: 0.000
# Training...
# matches: 5 / 13
# [Epoch 2 | Batch 0] Total: 4.8581 | Coord: 159.6937 | Obj: 27.6414 | NoObj: 23.1403 | Class: 100.4441
# matches: 5 / 11
# [Epoch 2 | Batch 1] Total: 4.5788 | Coord: 147.0728 | Obj: 25.3379 | NoObj: 23.1253 | Class: 97.5086
# matches: 10 / 16
# [Epoch 2 | Batch 2] Total: 4.6307 | Coord: 143.9483 | Obj: 26.5240 | NoObj: 23.1153 | Class: 102.7763
# matches: 2 / 13
# [Epoch 2 | Batch 3] Total: 4.2463 | Coord: 134.8157 | Obj: 24.6943 | NoObj: 23.1728 | Class: 89.0784
# matches: 1 / 14
# [Epoch 2 | Batch 4] Total: 5.4328 | Coord: 180.6689 | Obj: 30.2711 | NoObj: 23.0878 | Class: 113.6743
# matches: 2 / 18
# [Epoch 2 | Batch 5] Total: 5.1694 | Coord: 170.6508 | Obj: 29.7008 | NoObj: 23.1053 | Class: 107.3840
# matches: 1 / 15
# [Epoch 2 | Batch 6] Total: 4.6438 | Coord: 151.0357 | Obj: 26.7982 | NoObj: 23.1228 | Class: 96.2446
# matches: 1 / 11
# [Epoch 2 | Batch 7] Total: 4.9101 | Coord: 159.1355 | Obj: 28.8153 | NoObj: 23.0928 | Class: 103.2037
# matches: 1 / 21
# [Epoch 2 | Batch 8] Total: 5.7744 | Coord: 190.1308 | Obj: 33.6705 | NoObj: 23.0553 | Class: 122.7076
# matches: 1 / 15
# [Epoch 2 | Batch 9] Total: 5.5677 | Coord: 185.9595 | Obj: 31.4672 | NoObj: 23.0753 | Class: 115.8297
# matches: 1 / 18
# [Epoch 2 | Batch 10] Total: 5.7765 | Coord: 194.1840 | Obj: 33.2406 | NoObj: 23.0678 | Class: 119.2060
# matches: 1 / 11
# [Epoch 2 | Batch 11] Total: 4.8856 | Coord: 165.2959 | Obj: 27.1566 | NoObj: 23.1478 | Class: 97.0774
# matches: 3 / 18
# [Epoch 2 | Batch 12] Total: 4.9639 | Coord: 165.1501 | Obj: 28.7189 | NoObj: 23.1203 | Class: 100.6997
# matches: 4 / 11
# [Epoch 2 | Batch 13] Total: 5.5873 | Coord: 182.1696 | Obj: 32.4717 | NoObj: 23.0678 | Class: 119.8765
# matches: 7 / 15
# [Epoch 2 | Batch 14] Total: 4.9333 | Coord: 163.9148 | Obj: 26.7967 | NoObj: 23.1228 | Class: 101.8982
# matches: 4 / 13
# [Epoch 2 | Batch 15] Total: 4.2974 | Coord: 138.7245 | Obj: 24.0851 | NoObj: 23.1803 | Class: 89.0439
# matches: 2 / 18
# [Epoch 2 | Batch 16] Total: 5.6651 | Coord: 196.2298 | Obj: 32.7803 | NoObj: 23.0728 | Class: 110.4842
# matches: 6 / 17
# [Epoch 2 | Batch 17] Total: 5.5364 | Coord: 180.6465 | Obj: 32.2339 | NoObj: 23.0728 | Class: 118.3736
# matches: 3 / 17
# [Epoch 2 | Batch 18] Total: 5.0167 | Coord: 173.3712 | Obj: 29.0887 | NoObj: 23.1328 | Class: 95.4794
# matches: 3 / 12
# [Epoch 2 | Batch 19] Total: 5.1604 | Coord: 170.5742 | Obj: 29.0580 | NoObj: 23.1253 | Class: 107.5096
# matches: 1 / 15
# [Epoch 2 | Batch 20] Total: 4.6751 | Coord: 154.7717 | Obj: 26.6469 | NoObj: 23.1453 | Class: 94.6445
# matches: 2 / 16
# [Epoch 2 | Batch 21] Total: 5.3868 | Coord: 170.3410 | Obj: 31.4719 | NoObj: 23.0678 | Class: 119.8733
# matches: 2 / 15
# [Epoch 2 | Batch 22] Total: 6.0028 | Coord: 198.2461 | Obj: 35.2244 | NoObj: 23.0378 | Class: 127.6715
# matches: 0 / 15
# [Epoch 2 | Batch 23] Total: 5.1032 | Coord: 176.6925 | Obj: 28.1218 | NoObj: 23.1453 | Class: 98.6444
# matches: 4 / 20
# [Epoch 2 | Batch 24] Total: 4.6283 | Coord: 153.7343 | Obj: 27.0488 | NoObj: 23.1528 | Class: 92.2783
# Validating...
# matches: 0 / 16
# matches: 1 / 20
# matches: 4 / 13
# matches: 8 / 14
# matches: 7 / 11
# matches: 1 / 13
# matches: 6 / 11
# Training Loss: 5.097237434387207
# Validation Loss: 5.519831714630127
#
#
# Epoch 3/10 - IOU threshold: 0.001
# Training...
# matches: 3 / 15
# [Epoch 3 | Batch 0] Total: 5.6079 | Coord: 198.3827 | Obj: 31.4777 | NoObj: 23.1028 | Class: 105.9419
# matches: 1 / 12
# [Epoch 3 | Batch 1] Total: 5.2130 | Coord: 177.5716 | Obj: 29.4239 | NoObj: 23.1253 | Class: 103.5100
# matches: 9 / 18
# [Epoch 3 | Batch 2] Total: 5.4380 | Coord: 176.8852 | Obj: 32.1356 | NoObj: 23.0778 | Class: 115.9358
# matches: 1 / 17
# [Epoch 3 | Batch 3] Total: 5.6067 | Coord: 185.2381 | Obj: 32.6486 | NoObj: 23.0678 | Class: 117.8725
# matches: 2 / 17
# [Epoch 3 | Batch 4] Total: 5.1112 | Coord: 174.9907 | Obj: 29.2328 | NoObj: 23.1153 | Class: 99.7760
# matches: 3 / 11
# [Epoch 3 | Batch 5] Total: 5.1810 | Coord: 168.5373 | Obj: 30.1605 | NoObj: 23.0828 | Class: 109.8037
# matches: 1 / 14
# [Epoch 3 | Batch 6] Total: 4.5941 | Coord: 154.3198 | Obj: 25.0392 | NoObj: 23.1503 | Class: 91.5103
# matches: 1 / 13
# [Epoch 3 | Batch 7] Total: 5.3316 | Coord: 176.2461 | Obj: 30.2894 | NoObj: 23.1103 | Class: 111.5757
# matches: 12 / 20
# [Epoch 3 | Batch 8] Total: 5.0376 | Coord: 165.9473 | Obj: 28.9787 | NoObj: 23.1053 | Class: 104.3744
# matches: 1 / 13
# [Epoch 3 | Batch 9] Total: 5.4434 | Coord: 184.4939 | Obj: 30.8997 | NoObj: 23.0928 | Class: 109.8928
# matches: 1 / 14
# [Epoch 3 | Batch 10] Total: 5.1814 | Coord: 166.9293 | Obj: 29.5465 | NoObj: 23.1128 | Class: 112.0184
# matches: 0 / 18
# [Epoch 3 | Batch 11] Total: 4.3971 | Coord: 143.8510 | Obj: 23.2086 | NoObj: 23.1753 | Class: 91.1796
# matches: 4 / 13
# [Epoch 3 | Batch 12] Total: 4.9075 | Coord: 161.3004 | Obj: 28.0173 | NoObj: 23.1203 | Class: 101.6430
# matches: 3 / 11
# [Epoch 3 | Batch 13] Total: 4.3897 | Coord: 146.3300 | Obj: 25.0508 | NoObj: 23.1803 | Class: 86.3798
# matches: 2 / 17
# [Epoch 3 | Batch 14] Total: 5.1925 | Coord: 178.8320 | Obj: 30.2606 | NoObj: 23.1153 | Class: 100.1094
# matches: 5 / 11
# [Epoch 3 | Batch 15] Total: 4.3060 | Coord: 134.5680 | Obj: 24.7114 | NoObj: 23.1578 | Class: 93.1452
# matches: 3 / 18
# [Epoch 3 | Batch 16] Total: 5.9373 | Coord: 206.1089 | Obj: 32.3197 | NoObj: 23.0828 | Class: 118.4742
# matches: 4 / 12
# [Epoch 3 | Batch 17] Total: 4.6331 | Coord: 150.2576 | Obj: 26.2140 | NoObj: 23.1353 | Class: 96.9105
# matches: 0 / 15
# [Epoch 3 | Batch 18] Total: 4.4770 | Coord: 146.0774 | Obj: 25.4020 | NoObj: 23.1678 | Class: 91.8792
# matches: 1 / 15
# [Epoch 3 | Batch 19] Total: 5.7553 | Coord: 193.8412 | Obj: 32.5547 | NoObj: 23.0678 | Class: 118.8733
# matches: 8 / 16
# [Epoch 3 | Batch 20] Total: 5.3064 | Coord: 174.6854 | Obj: 29.9286 | NoObj: 23.0853 | Class: 111.9076
# matches: 2 / 14
# [Epoch 3 | Batch 21] Total: 5.5912 | Coord: 188.4347 | Obj: 31.8435 | NoObj: 23.0828 | Class: 114.4741
# matches: 6 / 21
# [Epoch 3 | Batch 22] Total: 5.3631 | Coord: 181.5382 | Obj: 30.8635 | NoObj: 23.0978 | Class: 107.7417
# matches: 2 / 16
# [Epoch 3 | Batch 23] Total: 5.8084 | Coord: 196.2136 | Obj: 33.5605 | NoObj: 23.0603 | Class: 118.9061
# matches: 1 / 13
# [Epoch 3 | Batch 24] Total: 4.9727 | Coord: 156.9085 | Obj: 29.3011 | NoObj: 23.1028 | Class: 108.9420
# Validating...
# matches: 10 / 16
# matches: 7 / 16
# matches: 1 / 12
# matches: 4 / 20
# matches: 4 / 14
# matches: 1 / 16
# matches: 2 / 7
# Training Loss: 5.15131441116333
# Validation Loss: 5.539977531433106
#
#
# Epoch 4/10 - IOU threshold: 0.004
# Training...
# matches: 1 / 17
# [Epoch 4 | Batch 0] Total: 4.7563 | Coord: 151.6842 | Obj: 26.7783 | NoObj: 23.1328 | Class: 102.8103
# matches: 5 / 17
# [Epoch 4 | Batch 1] Total: 4.4047 | Coord: 139.2334 | Obj: 24.9269 | NoObj: 23.1603 | Class: 94.5787
# matches: 5 / 16
# [Epoch 4 | Batch 2] Total: 5.1064 | Coord: 166.7371 | Obj: 29.1853 | NoObj: 23.0828 | Class: 107.8075
# matches: 1 / 16
# [Epoch 4 | Batch 3] Total: 5.1500 | Coord: 175.0472 | Obj: 28.4582 | NoObj: 23.1203 | Class: 102.9764
# matches: 1 / 18
# [Epoch 4 | Batch 4] Total: 4.6694 | Coord: 152.8669 | Obj: 26.4140 | NoObj: 23.1478 | Class: 96.4113
# matches: 2 / 18
# [Epoch 4 | Batch 5] Total: 5.0229 | Coord: 166.9000 | Obj: 27.4677 | NoObj: 23.1203 | Class: 103.9763
# matches: 2 / 15
# [Epoch 4 | Batch 6] Total: 4.3992 | Coord: 148.7769 | Obj: 25.1093 | NoObj: 23.1828 | Class: 84.4800
# matches: 4 / 11
# [Epoch 4 | Batch 7] Total: 4.6048 | Coord: 157.3094 | Obj: 25.1427 | NoObj: 23.1728 | Class: 89.0794
# matches: 2 / 21
# [Epoch 4 | Batch 8] Total: 5.2726 | Coord: 175.7679 | Obj: 30.7096 | NoObj: 23.0928 | Class: 107.8747
# matches: 3 / 15
# [Epoch 4 | Batch 9] Total: 4.9949 | Coord: 169.7895 | Obj: 28.5847 | NoObj: 23.1253 | Class: 98.1766
# matches: 0 / 14
# [Epoch 4 | Batch 10] Total: 4.5485 | Coord: 143.6949 | Obj: 26.3607 | NoObj: 23.1353 | Class: 97.9106
# matches: 6 / 18
# [Epoch 4 | Batch 11] Total: 4.3600 | Coord: 134.1830 | Obj: 25.6298 | NoObj: 23.1478 | Class: 96.0779
# matches: 3 / 14
# [Epoch 4 | Batch 12] Total: 4.7226 | Coord: 156.1367 | Obj: 26.3215 | NoObj: 23.1453 | Class: 96.6445
# matches: 2 / 11
# [Epoch 4 | Batch 13] Total: 4.1898 | Coord: 140.4601 | Obj: 23.4870 | NoObj: 23.1879 | Class: 81.0136
# matches: 1 / 15
# [Epoch 4 | Batch 14] Total: 4.7342 | Coord: 145.4462 | Obj: 27.3444 | NoObj: 23.1228 | Class: 107.0764
# matches: 3 / 12
# [Epoch 4 | Batch 15] Total: 5.9334 | Coord: 184.7663 | Obj: 34.2096 | NoObj: 23.0228 | Class: 137.7372
# matches: 2 / 13
# [Epoch 4 | Batch 16] Total: 5.6898 | Coord: 192.0049 | Obj: 34.0705 | NoObj: 23.0628 | Class: 115.0063
# matches: 1 / 20
# [Epoch 4 | Batch 17] Total: 5.1491 | Coord: 172.2412 | Obj: 29.3600 | NoObj: 23.1003 | Class: 104.8418
# matches: 1 / 15
# [Epoch 4 | Batch 18] Total: 4.3507 | Coord: 136.2672 | Obj: 24.5674 | NoObj: 23.1653 | Class: 94.4456
# matches: 2 / 17
# [Epoch 4 | Batch 19] Total: 5.1141 | Coord: 164.3121 | Obj: 30.1495 | NoObj: 23.0978 | Class: 109.7416
# matches: 4 / 18
# [Epoch 4 | Batch 20] Total: 5.3175 | Coord: 177.7379 | Obj: 30.9460 | NoObj: 23.0928 | Class: 108.5413
# matches: 1 / 14
# [Epoch 4 | Batch 21] Total: 4.7553 | Coord: 154.1756 | Obj: 25.8097 | NoObj: 23.1428 | Class: 101.2109
# matches: 4 / 13
# [Epoch 4 | Batch 22] Total: 5.3220 | Coord: 182.6160 | Obj: 30.4341 | NoObj: 23.1153 | Class: 104.4427
# matches: 6 / 16
# [Epoch 4 | Batch 23] Total: 5.8196 | Coord: 190.7429 | Obj: 33.6156 | NoObj: 23.0553 | Class: 125.0391
# matches: 5 / 13
# [Epoch 4 | Batch 24] Total: 4.9711 | Coord: 171.8481 | Obj: 27.8185 | NoObj: 23.1378 | Class: 95.3440
# Validating...
# matches: 1 / 14
# matches: 1 / 13
# matches: 1 / 10
# matches: 3 / 20
# matches: 2 / 16
# matches: 7 / 16
# matches: 1 / 16
# Training Loss: 4.934346714019775
# Validation Loss: 5.1955266952514645
# Validation loss has decreased from 5.353395614624024 to 5.1955266952514645
# Saving model ...
#
#
# Epoch 5/10 - IOU threshold: 0.013
# Training...
# matches: 1 / 11
# [Epoch 5 | Batch 0] Total: 5.0058 | Coord: 154.0479 | Obj: 28.9481 | NoObj: 23.1028 | Class: 114.2753
# matches: 3 / 9
# [Epoch 5 | Batch 1] Total: 3.5349 | Coord: 100.8604 | Obj: 21.3029 | NoObj: 23.1929 | Class: 80.8805
# matches: 2 / 14
# [Epoch 5 | Batch 2] Total: 4.7574 | Coord: 150.2861 | Obj: 27.3973 | NoObj: 23.1128 | Class: 103.6759
# matches: 8 / 16
# [Epoch 5 | Batch 3] Total: 3.9137 | Coord: 118.4773 | Obj: 22.5402 | NoObj: 23.1778 | Class: 86.2797
# matches: 1 / 18
# [Epoch 5 | Batch 4] Total: 4.1482 | Coord: 120.9398 | Obj: 23.7800 | NoObj: 23.1528 | Class: 97.6116
# matches: 2 / 12
# [Epoch 5 | Batch 5] Total: 4.0554 | Coord: 118.4446 | Obj: 23.6945 | NoObj: 23.1603 | Class: 94.2453
# matches: 3 / 14
# [Epoch 5 | Batch 6] Total: 4.3557 | Coord: 133.7358 | Obj: 25.1369 | NoObj: 23.1478 | Class: 96.7446
# matches: 2 / 18
# [Epoch 5 | Batch 7] Total: 3.9857 | Coord: 121.6527 | Obj: 23.4089 | NoObj: 23.1753 | Class: 86.8462
# matches: 2 / 14
# [Epoch 5 | Batch 8] Total: 3.7992 | Coord: 118.2140 | Obj: 21.7622 | NoObj: 23.1954 | Class: 79.9807
# matches: 1 / 13
# [Epoch 5 | Batch 9] Total: 4.2483 | Coord: 132.5009 | Obj: 24.6794 | NoObj: 23.1678 | Class: 91.5458
# matches: 3 / 20
# [Epoch 5 | Batch 10] Total: 4.0651 | Coord: 128.8151 | Obj: 23.7941 | NoObj: 23.1803 | Class: 84.3799
# matches: 1 / 15
# [Epoch 5 | Batch 11] Total: 4.3987 | Coord: 136.4884 | Obj: 24.9283 | NoObj: 23.1528 | Class: 96.9449
# matches: 3 / 11
# [Epoch 5 | Batch 12] Total: 3.7352 | Coord: 114.6051 | Obj: 21.7328 | NoObj: 23.2004 | Class: 79.5144
# matches: 4 / 10
# [Epoch 5 | Batch 13] Total: 3.2933 | Coord: 96.7626 | Obj: 18.2907 | NoObj: 23.2329 | Class: 72.4829
# matches: 2 / 12
# [Epoch 5 | Batch 14] Total: 4.8387 | Coord: 147.2664 | Obj: 27.7246 | NoObj: 23.1103 | Class: 111.5757
# matches: 2 / 18
# [Epoch 5 | Batch 15] Total: 5.3358 | Coord: 168.7740 | Obj: 30.5723 | NoObj: 23.0728 | Class: 119.0735
# matches: 2 / 15
# [Epoch 5 | Batch 16] Total: 4.1772 | Coord: 133.4901 | Obj: 24.4950 | NoObj: 23.1753 | Class: 86.1795
# matches: 3 / 21
# [Epoch 5 | Batch 17] Total: 3.7431 | Coord: 114.0706 | Obj: 21.5173 | NoObj: 23.1904 | Class: 80.7804
# matches: 2 / 12
# [Epoch 5 | Batch 18] Total: 4.1897 | Coord: 127.8047 | Obj: 24.3697 | NoObj: 23.1578 | Class: 92.8119
# matches: 1 / 15
# [Epoch 5 | Batch 19] Total: 4.0866 | Coord: 126.4991 | Obj: 23.5596 | NoObj: 23.1703 | Class: 88.3126
# matches: 2 / 17
# [Epoch 5 | Batch 20] Total: 5.0760 | Coord: 162.8008 | Obj: 29.8919 | NoObj: 23.0978 | Class: 109.0750
# matches: 2 / 16
# [Epoch 5 | Batch 21] Total: 3.7619 | Coord: 117.3348 | Obj: 21.1766 | NoObj: 23.2054 | Class: 79.0480
# matches: 0 / 16
# [Epoch 5 | Batch 22] Total: 3.8973 | Coord: 120.5723 | Obj: 22.1672 | NoObj: 23.2079 | Class: 83.4814
# matches: 5 / 18
# [Epoch 5 | Batch 23] Total: 4.0871 | Coord: 126.7829 | Obj: 24.4388 | NoObj: 23.1753 | Class: 87.1795
# matches: 2 / 13
# [Epoch 5 | Batch 24] Total: 4.4377 | Coord: 142.9933 | Obj: 24.7411 | NoObj: 23.1653 | Class: 93.1122
# Validating...
# matches: 1 / 20
# matches: 0 / 12
# matches: 1 / 16
# matches: 1 / 16
# matches: 1 / 14
# matches: 3 / 15
# matches: 1 / 16
# Training Loss: 4.197113361358642
# Validation Loss: 4.499841995239258
# Validation loss has decreased from 5.1955266952514645 to 4.499841995239258
# Saving model ...
#
#
# Epoch 6/10 - IOU threshold: 0.031
# Training...
# matches: 0 / 18
# [Epoch 6 | Batch 0] Total: 2.9042 | Coord: 76.1946 | Obj: 17.0377 | NoObj: 23.2554 | Class: 69.3843
# matches: 6 / 12
# [Epoch 6 | Batch 1] Total: 3.0320 | Coord: 83.5291 | Obj: 17.2677 | NoObj: 23.2379 | Class: 70.0166
# matches: 1 / 12
# [Epoch 6 | Batch 2] Total: 2.6859 | Coord: 67.1629 | Obj: 15.4270 | NoObj: 23.2554 | Class: 66.0509
# matches: 1 / 15
# [Epoch 6 | Batch 3] Total: 2.7099 | Coord: 69.4081 | Obj: 15.6153 | NoObj: 23.2579 | Class: 65.1511
# matches: 3 / 13
# [Epoch 6 | Batch 4] Total: 2.6763 | Coord: 66.3384 | Obj: 14.9946 | NoObj: 23.2629 | Class: 66.6847
# matches: 5 / 17
# [Epoch 6 | Batch 5] Total: 2.9200 | Coord: 79.8686 | Obj: 17.0390 | NoObj: 23.2554 | Class: 66.7176
# matches: 3 / 15
# [Epoch 6 | Batch 6] Total: 2.6889 | Coord: 65.1727 | Obj: 15.7139 | NoObj: 23.2529 | Class: 67.9508
# matches: 2 / 15
# [Epoch 6 | Batch 7] Total: 2.6329 | Coord: 65.0466 | Obj: 15.3053 | NoObj: 23.2679 | Class: 64.8850
# matches: 1 / 18
# [Epoch 6 | Batch 8] Total: 2.3787 | Coord: 56.2669 | Obj: 13.4570 | NoObj: 23.2929 | Class: 59.2198
# matches: 2 / 15
# [Epoch 6 | Batch 9] Total: 2.6899 | Coord: 71.9128 | Obj: 14.6785 | NoObj: 23.2779 | Class: 62.2856
# matches: 1 / 21
# [Epoch 6 | Batch 10] Total: 2.8330 | Coord: 61.3210 | Obj: 16.9144 | NoObj: 23.2254 | Class: 79.8492
# matches: 1 / 11
# [Epoch 6 | Batch 11] Total: 2.7210 | Coord: 70.0794 | Obj: 14.9640 | NoObj: 23.2504 | Class: 65.8506
# matches: 1 / 14
# [Epoch 6 | Batch 12] Total: 2.5611 | Coord: 66.7069 | Obj: 14.4339 | NoObj: 23.2829 | Class: 59.4859
# matches: 5 / 12
# [Epoch 6 | Batch 13] Total: 2.6974 | Coord: 68.4114 | Obj: 14.8394 | NoObj: 23.2654 | Class: 66.1182
# matches: 3 / 16
# [Epoch 6 | Batch 14] Total: 2.8766 | Coord: 72.8636 | Obj: 15.9078 | NoObj: 23.2479 | Class: 72.0838
# matches: 1 / 14
# [Epoch 6 | Batch 15] Total: 3.1245 | Coord: 76.8661 | Obj: 17.2842 | NoObj: 23.2029 | Class: 82.6145
# matches: 3 / 13
# [Epoch 6 | Batch 16] Total: 2.7879 | Coord: 70.6392 | Obj: 16.2241 | NoObj: 23.2454 | Class: 68.3170
# matches: 1 / 16
# [Epoch 6 | Batch 17] Total: 3.2648 | Coord: 88.5859 | Obj: 19.2637 | NoObj: 23.2179 | Class: 77.8821
# matches: 1 / 13
# [Epoch 6 | Batch 18] Total: 2.7624 | Coord: 67.4231 | Obj: 14.8309 | NoObj: 23.2529 | Class: 71.2841
# matches: 1 / 18
# [Epoch 6 | Batch 19] Total: 2.9565 | Coord: 80.5963 | Obj: 16.8535 | NoObj: 23.2504 | Class: 68.5173
# matches: 0 / 20
# [Epoch 6 | Batch 20] Total: 2.5575 | Coord: 65.5806 | Obj: 14.2008 | NoObj: 23.2779 | Class: 60.6189
# matches: 0 / 14
# [Epoch 6 | Batch 21] Total: 2.5442 | Coord: 67.2467 | Obj: 14.4027 | NoObj: 23.2929 | Class: 57.8865
# matches: 0 / 12
# [Epoch 6 | Batch 22] Total: 2.7445 | Coord: 68.2231 | Obj: 15.0131 | NoObj: 23.2579 | Class: 69.1511
# matches: 0 / 16
# [Epoch 6 | Batch 23] Total: 2.8807 | Coord: 76.5089 | Obj: 16.1882 | NoObj: 23.2479 | Class: 68.4171
# matches: 4 / 12
# [Epoch 6 | Batch 24] Total: 3.0544 | Coord: 81.9690 | Obj: 17.7988 | NoObj: 23.2329 | Class: 72.4830
# Validating...
# matches: 1 / 20
# matches: 0 / 16
# matches: 1 / 16
# matches: 2 / 11
# matches: 3 / 16
# matches: 1 / 16
# matches: 7 / 13
# Training Loss: 2.787401065826416
# Validation Loss: 3.0227376079559325
# Validation loss has decreased from 4.499841995239258 to 3.0227376079559325
# Saving model ...
#
#
# Epoch 7/10 - IOU threshold: 0.065
# Training...
# matches: 0 / 18
# [Epoch 7 | Batch 0] Total: 1.8035 | Coord: 34.9207 | Obj: 9.3719 | NoObj: 23.3404 | Class: 47.7893
# matches: 1 / 13
# [Epoch 7 | Batch 1] Total: 1.4809 | Coord: 28.2235 | Obj: 6.7853 | NoObj: 23.3804 | Class: 36.3917
# matches: 0 / 11
# [Epoch 7 | Batch 2] Total: 1.5577 | Coord: 31.3259 | Obj: 7.3382 | NoObj: 23.3704 | Class: 37.6578
# matches: 0 / 12
# [Epoch 7 | Batch 3] Total: 1.5985 | Coord: 28.8481 | Obj: 7.3495 | NoObj: 23.3479 | Class: 42.7564
# matches: 2 / 14
# [Epoch 7 | Batch 4] Total: 1.5294 | Coord: 27.8545 | Obj: 7.6402 | NoObj: 23.3629 | Class: 39.0240
# matches: 0 / 14
# [Epoch 7 | Batch 5] Total: 1.4293 | Coord: 23.3659 | Obj: 6.7487 | NoObj: 23.3704 | Class: 37.9911
# matches: 2 / 18
# [Epoch 7 | Batch 6] Total: 1.6743 | Coord: 30.7854 | Obj: 8.5708 | NoObj: 23.3404 | Class: 44.4560
# matches: 0 / 20
# [Epoch 7 | Batch 7] Total: 1.5526 | Coord: 27.4547 | Obj: 7.6251 | NoObj: 23.3604 | Class: 40.9239
# matches: 3 / 16
# [Epoch 7 | Batch 8] Total: 1.6100 | Coord: 27.7689 | Obj: 8.0640 | NoObj: 23.3504 | Class: 43.8566
# matches: 1 / 13
# [Epoch 7 | Batch 9] Total: 1.5948 | Coord: 29.4792 | Obj: 7.8405 | NoObj: 23.3554 | Class: 41.3902
# matches: 2 / 16
# [Epoch 7 | Batch 10] Total: 1.8103 | Coord: 33.3602 | Obj: 8.5511 | NoObj: 23.3279 | Class: 50.6219
# matches: 0 / 17
# [Epoch 7 | Batch 11] Total: 1.7061 | Coord: 32.7677 | Obj: 8.6243 | NoObj: 23.3404 | Class: 44.4560
# matches: 2 / 13
# [Epoch 7 | Batch 12] Total: 1.5705 | Coord: 29.4231 | Obj: 7.3680 | NoObj: 23.3629 | Class: 40.3573
# matches: 0 / 21
# [Epoch 7 | Batch 13] Total: 1.9289 | Coord: 35.0981 | Obj: 9.5561 | NoObj: 23.3079 | Class: 55.4874
# matches: 0 / 18
# [Epoch 7 | Batch 14] Total: 1.4703 | Coord: 27.3225 | Obj: 7.2085 | NoObj: 23.3754 | Class: 36.1914
# matches: 0 / 18
# [Epoch 7 | Batch 15] Total: 1.8439 | Coord: 31.9313 | Obj: 8.4389 | NoObj: 23.3204 | Class: 54.3215
# matches: 0 / 15
# [Epoch 7 | Batch 16] Total: 1.9586 | Coord: 38.7179 | Obj: 9.7091 | NoObj: 23.3029 | Class: 53.6204
# matches: 3 / 15
# [Epoch 7 | Batch 17] Total: 1.6197 | Coord: 30.7049 | Obj: 8.1050 | NoObj: 23.3579 | Class: 41.4904
# matches: 0 / 17
# [Epoch 7 | Batch 18] Total: 1.6351 | Coord: 29.1233 | Obj: 7.9837 | NoObj: 23.3504 | Class: 44.1899
# matches: 1 / 14
# [Epoch 7 | Batch 19] Total: 1.6076 | Coord: 31.9290 | Obj: 8.3174 | NoObj: 23.3529 | Class: 39.2901
# matches: 0 / 15
# [Epoch 7 | Batch 20] Total: 1.6711 | Coord: 33.4521 | Obj: 8.0852 | NoObj: 23.3554 | Class: 42.0569
# matches: 1 / 11
# [Epoch 7 | Batch 21] Total: 1.3949 | Coord: 24.3736 | Obj: 6.6953 | NoObj: 23.3829 | Class: 34.8252
# matches: 0 / 15
# [Epoch 7 | Batch 22] Total: 1.5039 | Coord: 28.7201 | Obj: 7.1698 | NoObj: 23.3704 | Class: 36.9911
# matches: 2 / 16
# [Epoch 7 | Batch 23] Total: 1.7011 | Coord: 30.3537 | Obj: 8.2873 | NoObj: 23.3429 | Class: 46.8895
# matches: 2 / 15
# [Epoch 7 | Batch 24] Total: 2.2107 | Coord: 45.4179 | Obj: 11.9174 | NoObj: 23.2679 | Class: 60.8850
# Validating...
# matches: 4 / 16
# matches: 0 / 16
# matches: 0 / 20
# matches: 0 / 16
# matches: 1 / 14
# matches: 0 / 12
# matches: 2 / 7
# Training Loss: 1.658545298576355
# Validation Loss: 1.829560594558716
# Validation loss has decreased from 3.0227376079559325 to 1.829560594558716
# Saving model ...
#
#
# Epoch 8/10 - IOU threshold: 0.120
# Training...
# matches: 1 / 15
# [Epoch 8 | Batch 0] Total: 1.1769 | Coord: 13.2503 | Obj: 3.8894 | NoObj: 23.3904 | Class: 34.7923
# matches: 0 / 14
# [Epoch 8 | Batch 1] Total: 0.8274 | Coord: 7.6865 | Obj: 2.3896 | NoObj: 23.4479 | Class: 19.4290
# matches: 0 / 15
# [Epoch 8 | Batch 2] Total: 0.9852 | Coord: 11.8659 | Obj: 2.6710 | NoObj: 23.4229 | Class: 25.0942
# matches: 0 / 17
# [Epoch 8 | Batch 3] Total: 0.9474 | Coord: 10.9535 | Obj: 2.6227 | NoObj: 23.4279 | Class: 23.6279
# matches: 0 / 17
# [Epoch 8 | Batch 4] Total: 1.0525 | Coord: 13.6118 | Obj: 3.7474 | NoObj: 23.4104 | Class: 26.5935
# matches: 1 / 11
# [Epoch 8 | Batch 5] Total: 0.7372 | Coord: 5.1278 | Obj: 1.8677 | NoObj: 23.4554 | Class: 16.7295
# matches: 0 / 15
# [Epoch 8 | Batch 6] Total: 1.0274 | Coord: 13.4116 | Obj: 3.5961 | NoObj: 23.4204 | Class: 25.3274
# matches: 0 / 16
# [Epoch 8 | Batch 7] Total: 1.0439 | Coord: 11.7697 | Obj: 3.9311 | NoObj: 23.4129 | Class: 27.6936
# matches: 0 / 18
# [Epoch 8 | Batch 8] Total: 1.0911 | Coord: 11.9828 | Obj: 4.0526 | NoObj: 23.4054 | Class: 30.3932
# matches: 0 / 13
# [Epoch 8 | Batch 9] Total: 0.8430 | Coord: 9.7677 | Obj: 2.6142 | NoObj: 23.4404 | Class: 18.1286
# matches: 0 / 15
# [Epoch 8 | Batch 10] Total: 1.0362 | Coord: 12.2897 | Obj: 4.0214 | NoObj: 23.4104 | Class: 26.5935
# matches: 0 / 11
# [Epoch 8 | Batch 11] Total: 0.8220 | Coord: 8.5494 | Obj: 2.2867 | NoObj: 23.4454 | Class: 18.3289
# matches: 3 / 13
# [Epoch 8 | Batch 12] Total: 1.0507 | Coord: 14.5054 | Obj: 3.7344 | NoObj: 23.4104 | Class: 25.5935
# matches: 0 / 18
# [Epoch 8 | Batch 13] Total: 0.9685 | Coord: 11.5100 | Obj: 2.9555 | NoObj: 23.4229 | Class: 24.0942
# matches: 2 / 13
# [Epoch 8 | Batch 14] Total: 1.1785 | Coord: 14.8559 | Obj: 4.4094 | NoObj: 23.3979 | Class: 32.7594
# matches: 2 / 16
# [Epoch 8 | Batch 15] Total: 1.1033 | Coord: 11.5563 | Obj: 3.7933 | NoObj: 23.4004 | Class: 31.8596
# matches: 0 / 12
# [Epoch 8 | Batch 16] Total: 1.0989 | Coord: 14.9340 | Obj: 3.4932 | NoObj: 23.4079 | Class: 28.4933
# matches: 2 / 13
# [Epoch 8 | Batch 17] Total: 0.9146 | Coord: 11.4311 | Obj: 2.8448 | NoObj: 23.4329 | Class: 20.8282
# matches: 0 / 11
# [Epoch 8 | Batch 18] Total: 1.0325 | Coord: 11.1866 | Obj: 3.1196 | NoObj: 23.4129 | Class: 28.3603
# matches: 0 / 16
# [Epoch 8 | Batch 19] Total: 0.8027 | Coord: 6.7531 | Obj: 1.9459 | NoObj: 23.4429 | Class: 19.2287
# matches: 1 / 15
# [Epoch 8 | Batch 20] Total: 1.0515 | Coord: 11.2868 | Obj: 3.7731 | NoObj: 23.4079 | Class: 28.8267
# matches: 0 / 11
# [Epoch 8 | Batch 21] Total: 0.7206 | Coord: 6.7178 | Obj: 2.0138 | NoObj: 23.4604 | Class: 13.9298
# matches: 0 / 21
# [Epoch 8 | Batch 22] Total: 1.0704 | Coord: 13.8847 | Obj: 4.1814 | NoObj: 23.4129 | Class: 27.0270
# matches: 2 / 20
# [Epoch 8 | Batch 23] Total: 1.1259 | Coord: 16.8787 | Obj: 3.6386 | NoObj: 23.4154 | Class: 28.1271
# matches: 3 / 15
# [Epoch 8 | Batch 24] Total: 1.1556 | Coord: 15.2245 | Obj: 3.9854 | NoObj: 23.3879 | Class: 31.3588
# Validating...
# matches: 1 / 16
# matches: 1 / 13
# matches: 0 / 16
# matches: 0 / 20
# matches: 0 / 15
# matches: 0 / 10
# matches: 0 / 12
# Training Loss: 0.994550518989563
# Validation Loss: 0.9982907748222352
# Validation loss has decreased from 1.829560594558716 to 0.9982907748222352
# Saving model ...
#
#
# Epoch 9/10 - IOU threshold: 0.205
# Training...
# matches: 0 / 20
# [Epoch 9 | Batch 0] Total: 0.7335 | Coord: 6.1181 | Obj: 1.0007 | NoObj: 23.4629 | Class: 16.3633
# matches: 2 / 12
# [Epoch 9 | Batch 1] Total: 0.7611 | Coord: 6.6197 | Obj: 1.2380 | NoObj: 23.4554 | Class: 17.3962
# matches: 0 / 14
# [Epoch 9 | Batch 2] Total: 0.6931 | Coord: 4.2611 | Obj: 0.8124 | NoObj: 23.4579 | Class: 15.8296
# matches: 0 / 17
# [Epoch 9 | Batch 3] Total: 0.5793 | Coord: 2.9697 | Obj: 0.5592 | NoObj: 23.4804 | Class: 10.0643
# matches: 0 / 12
# [Epoch 9 | Batch 4] Total: 0.6545 | Coord: 3.8219 | Obj: 1.1379 | NoObj: 23.4654 | Class: 13.4634
# matches: 0 / 16
# [Epoch 9 | Batch 5] Total: 0.4909 | Coord: 1.2356 | Obj: 0.3558 | NoObj: 23.4954 | Class: 6.3319
# matches: 0 / 15
# [Epoch 9 | Batch 6] Total: 0.6527 | Coord: 3.3243 | Obj: 0.9557 | NoObj: 23.4629 | Class: 14.0299
# matches: 0 / 15
# [Epoch 9 | Batch 7] Total: 0.6948 | Coord: 4.4491 | Obj: 1.0631 | NoObj: 23.4579 | Class: 15.4963
# matches: 0 / 18
# [Epoch 9 | Batch 8] Total: 0.5321 | Coord: 2.0084 | Obj: 0.5277 | NoObj: 23.4879 | Class: 8.0314
# matches: 1 / 15
# [Epoch 9 | Batch 9] Total: 0.7224 | Coord: 4.0821 | Obj: 0.9687 | NoObj: 23.4554 | Class: 17.7295
# matches: 0 / 12
# [Epoch 9 | Batch 10] Total: 0.7193 | Coord: 3.9503 | Obj: 1.0012 | NoObj: 23.4529 | Class: 17.6293
# matches: 0 / 15
# [Epoch 9 | Batch 11] Total: 0.5412 | Coord: 1.6898 | Obj: 0.4307 | NoObj: 23.4879 | Class: 9.0314
# matches: 1 / 14
# [Epoch 9 | Batch 12] Total: 0.5411 | Coord: 1.4491 | Obj: 0.5370 | NoObj: 23.4829 | Class: 9.1644
# matches: 2 / 12
# [Epoch 9 | Batch 13] Total: 0.7428 | Coord: 5.1874 | Obj: 1.0418 | NoObj: 23.4504 | Class: 17.8625
# matches: 0 / 18
# [Epoch 9 | Batch 14] Total: 0.4839 | Coord: 1.2547 | Obj: 0.5554 | NoObj: 23.4954 | Class: 5.6652
# matches: 0 / 15
# [Epoch 9 | Batch 15] Total: 0.5962 | Coord: 3.6109 | Obj: 0.7695 | NoObj: 23.4779 | Class: 10.2975
# matches: 1 / 18
# [Epoch 9 | Batch 16] Total: 0.7446 | Coord: 4.1273 | Obj: 1.3196 | NoObj: 23.4479 | Class: 18.7624
# matches: 0 / 16
# [Epoch 9 | Batch 17] Total: 0.6911 | Coord: 4.7765 | Obj: 0.7545 | NoObj: 23.4679 | Class: 15.2302
# matches: 0 / 14
# [Epoch 9 | Batch 18] Total: 0.6722 | Coord: 4.3135 | Obj: 0.9842 | NoObj: 23.4604 | Class: 14.2631
# matches: 0 / 21
# [Epoch 9 | Batch 19] Total: 0.5462 | Coord: 2.4029 | Obj: 0.5748 | NoObj: 23.4829 | Class: 8.4978
# matches: 0 / 13
# [Epoch 9 | Batch 20] Total: 0.6286 | Coord: 3.0678 | Obj: 0.7994 | NoObj: 23.4679 | Class: 12.8969
# matches: 1 / 14
# [Epoch 9 | Batch 21] Total: 0.5333 | Coord: 2.3555 | Obj: 0.5881 | NoObj: 23.4879 | Class: 7.6981
# matches: 1 / 13
# [Epoch 9 | Batch 22] Total: 0.5334 | Coord: 2.7083 | Obj: 0.4732 | NoObj: 23.4904 | Class: 7.4649
# matches: 0 / 15
# [Epoch 9 | Batch 23] Total: 0.5809 | Coord: 2.6536 | Obj: 0.6457 | NoObj: 23.4804 | Class: 10.3976
# matches: 0 / 18
# [Epoch 9 | Batch 24] Total: 0.6380 | Coord: 3.2238 | Obj: 0.8088 | NoObj: 23.4704 | Class: 13.3304
# Validating...
# matches: 0 / 13
# matches: 0 / 12
# matches: 1 / 16
# matches: 1 / 16
# matches: 0 / 16
# matches: 0 / 20
# matches: 0 / 10
# Training Loss: 0.6282919669151306
# Validation Loss: 0.6545631074905396
# Validation loss has decreased from 0.9982907748222352 to 0.6545631074905396
# Saving model ...
#
#
# Epoch 10/10 - IOU threshold: 0.328
# Training...
# matches: 0 / 9
# [Epoch 10 | Batch 0] Total: 0.5006 | Coord: 1.4870 | Obj: 0.1637 | NoObj: 23.4929 | Class: 6.8984
# matches: 0 / 10
# [Epoch 10 | Batch 1] Total: 0.4405 | Coord: 0.6076 | Obj: 0.1141 | NoObj: 23.5029 | Class: 3.9656
# matches: 0 / 17
# [Epoch 10 | Batch 2] Total: 0.4749 | Coord: 1.1925 | Obj: 0.1690 | NoObj: 23.5004 | Class: 5.5321
# matches: 0 / 21
# [Epoch 10 | Batch 3] Total: 0.5279 | Coord: 1.2873 | Obj: 0.1851 | NoObj: 23.4829 | Class: 8.8311
# matches: 0 / 18
# [Epoch 10 | Batch 4] Total: 0.4647 | Coord: 0.9333 | Obj: 0.1110 | NoObj: 23.5004 | Class: 5.1988
# matches: 0 / 9
# [Epoch 10 | Batch 5] Total: 0.4792 | Coord: 0.6894 | Obj: 0.0482 | NoObj: 23.4979 | Class: 6.4320
# matches: 0 / 13
# [Epoch 10 | Batch 6] Total: 0.4585 | Coord: 0.7672 | Obj: 0.1059 | NoObj: 23.5029 | Class: 4.9656
# matches: 0 / 20
# [Epoch 10 | Batch 7] Total: 0.5237 | Coord: 1.7665 | Obj: 0.1298 | NoObj: 23.4904 | Class: 8.1316
# matches: 0 / 17
# [Epoch 10 | Batch 8] Total: 0.3963 | Coord: 0.1305 | Obj: 0.0234 | NoObj: 23.5129 | Class: 1.6996
# matches: 0 / 14
# [Epoch 10 | Batch 9] Total: 0.4373 | Coord: 0.6117 | Obj: 0.1359 | NoObj: 23.5054 | Class: 3.7324
# matches: 0 / 16
# [Epoch 10 | Batch 10] Total: 0.4632 | Coord: 1.1183 | Obj: 0.0553 | NoObj: 23.5029 | Class: 4.9656
# matches: 0 / 14
# [Epoch 10 | Batch 11] Total: 0.4855 | Coord: 1.0667 | Obj: 0.1782 | NoObj: 23.4954 | Class: 6.3319
# matches: 0 / 15
# [Epoch 10 | Batch 12] Total: 0.4808 | Coord: 0.9942 | Obj: 0.1802 | NoObj: 23.4979 | Class: 6.0987
# matches: 0 / 17
# [Epoch 10 | Batch 13] Total: 0.4127 | Coord: 0.2473 | Obj: 0.0536 | NoObj: 23.5104 | Class: 2.5994
# matches: 0 / 14
# [Epoch 10 | Batch 14] Total: 0.4977 | Coord: 1.1178 | Obj: 0.1114 | NoObj: 23.4904 | Class: 7.1316
# matches: 1 / 13
# [Epoch 10 | Batch 15] Total: 0.4914 | Coord: 1.1098 | Obj: 0.2819 | NoObj: 23.4929 | Class: 6.5650
# matches: 0 / 18
# [Epoch 10 | Batch 16] Total: 0.4955 | Coord: 1.6709 | Obj: 0.1135 | NoObj: 23.4979 | Class: 6.4320
# matches: 1 / 18
# [Epoch 10 | Batch 17] Total: 0.4289 | Coord: 0.4055 | Obj: 0.0399 | NoObj: 23.5079 | Class: 3.4993
# matches: 1 / 15
# [Epoch 10 | Batch 18] Total: 0.4488 | Coord: 0.7971 | Obj: 0.1229 | NoObj: 23.5029 | Class: 4.2990
# matches: 0 / 18
# [Epoch 10 | Batch 19] Total: 0.4831 | Coord: 1.2017 | Obj: 0.1222 | NoObj: 23.4979 | Class: 6.0987
# matches: 0 / 16
# [Epoch 10 | Batch 20] Total: 0.4792 | Coord: 1.6780 | Obj: 0.0606 | NoObj: 23.4979 | Class: 5.4320
# matches: 0 / 15
# [Epoch 10 | Batch 21] Total: 0.4435 | Coord: 0.4748 | Obj: 0.1102 | NoObj: 23.5029 | Class: 4.2990
# matches: 1 / 16
# [Epoch 10 | Batch 22] Total: 0.4497 | Coord: 0.5672 | Obj: 0.0777 | NoObj: 23.5029 | Class: 4.6323
# matches: 0 / 12
# [Epoch 10 | Batch 23] Total: 0.4431 | Coord: 0.7230 | Obj: 0.0647 | NoObj: 23.5054 | Class: 4.0658
# matches: 0 / 15
# [Epoch 10 | Batch 24] Total: 0.4333 | Coord: 0.7402 | Obj: 0.0884 | NoObj: 23.5054 | Class: 3.3991
# Validating...
# matches: 1 / 14
# matches: 0 / 16
# matches: 0 / 20
# matches: 0 / 13
# matches: 0 / 16
# matches: 0 / 16
# matches: 0 / 7
# Training Loss: 0.4655993592739105
# Validation Loss: 0.49722866296768187
# Validation loss has decreased from 0.6545631074905396 to 0.49722866296768187
# Saving model ...
#
#
# Total Time for Training: 0:49:17

# %% [markdown]
# ---
# ## Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_trained.pt', weights_only=True))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ---
# ## Test the Trained Network

# %%
# track test loss
test_loss = 0.0
class_correct = [0. for _ in range(NUM_CLASSES)]
class_total = [0. for _ in range(NUM_CLASSES)]

# TODO: adjust TEST_CONFIDENCE_THRESHOLD and TEST_IOU_THRESHOLD
TEST_CONFIDENCE_THRESHOLD = CONFIDENCE_THRESHOLD
TEST_IOU_THRESHOLD = 0.328
print("Testing with confidence threshold:", TEST_CONFIDENCE_THRESHOLD, "and IOU threshold:", TEST_IOU_THRESHOLD)

model.eval()
for batch_idx, (data, target) in enumerate(test_loader):
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()

    with torch.no_grad():
        output = model(data)
        # calculate the batch loss
        loss, coord_loss, obj_loss, noobj_loss, class_loss = criterion(output, target, anchors, TEST_CONFIDENCE_THRESHOLD, TEST_IOU_THRESHOLD)
        test_loss += loss.item() * data.size(0)

    batch_size = data.size(0)

    for b in range(batch_size):
        preds = output[b]       # shape: [batch_size, S, S, num_anchors, 5 + num_classes]
        labels = target[b]      # shape: [M, 5 + num_classes]

        labels = labels[labels[:, 0] != -1]  # remove padding
        preds = preds.view(-1, preds.shape[-1])
        # print("Sample pred after reshape:", preds[0])

        for gt in labels:
            gt_class = int(torch.argmax(gt[5:]).item())
            best_iou = 0
            best_pred_class = None

            assert preds.shape == (GRID_SIZE * GRID_SIZE * NUMBER_ANCHORS, 5 + NUM_CLASSES)
            for pred in preds:
                iou = calculate_iou(pred[:4], gt[1:5])
                if iou > best_iou:
                    best_iou = iou
                    best_pred_class = torch.argmax(pred[5:]).item()

            class_total[gt_class] += 1
            if best_iou > TEST_IOU_THRESHOLD:
                if best_pred_class == gt_class:
                    class_correct[gt_class] += 1

# average test loss
test_loss = test_loss / len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(NUM_CLASSES):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            CLASSES[i], 100 * class_correct[i] / class_total[i],
            class_correct[i], class_total[i]))
    else:
        print('Test Accuracy of %5s: N/A (no ground truth samples)' % (CLASSES[i]))

if sum(class_total) > 0:
    print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
        100. * sum(class_correct) / sum(class_total),
        sum(class_correct), sum(class_total)))
else:
    print('\nTest Accuracy (Overall): N/A (no valid ground truth boxes in test set)')
# Out:
# Testing with confidence threshold: 0.01 and IOU threshold: 0.328
# matches: 0 / 13
# matches: 0 / 13
# matches: 0 / 18
# matches: 0 / 12
# matches: 0 / 15
# matches: 0 / 12
# matches: 0 / 15
# matches: 0 / 17
# matches: 0 / 14
# matches: 0 / 13
# matches: 0 / 14
# matches: 0 / 28
# matches: 0 / 13
# matches: 0 / 16
# matches: 1 / 12
# matches: 0 / 19
# matches: 1 / 16
# matches: 0 / 27
# matches: 0 / 10
# matches: 0 / 13
# matches: 0 / 12
# matches: 0 / 14
# matches: 0 / 14
# matches: 1 / 16
# matches: 0 / 14
# matches: 0 / 18
# matches: 0 / 14
# matches: 0 / 12
# Test Loss: 0.482317
#
# Test Accuracy of  head:  1% (31/1803)
# Test Accuracy of helmet:  4% (195/4863)
# Test Accuracy of person: 27% (39/142)
#
# Test Accuracy (Overall):  3% (265/6808)

# %% [markdown]
# ## Visualize Sample Test Results

# %% [markdown]
# ### Non-Maximum Suppression Function
#
# This is to remove redundant overlapping boxes that the predicted the same object

# %%
import torchvision.ops as ops

def apply_nms(predictions, iou_threshold=TEST_IOU_THRESHOLD, conf_threshold=TEST_CONFIDENCE_THRESHOLD):
    boxes = []
    scores = []
    class_ids = []

    for pred in predictions:
        conf = pred[4].item()
        if conf < conf_threshold:
            continue

        class_score, class_id = torch.max(pred[5:], dim=0)
        total_score = conf * class_score.item()

        if total_score < conf_threshold:
            continue

        x, y, w, h = pred[0:4]
        x1 = x - w / 2
        y1 = y - h / 2
        x2 = x + w / 2
        y2 = y + h / 2

        boxes.append([x1, y1, x2, y2])
        scores.append(total_score)
        class_ids.append(class_id.item())

    if not boxes:
        return torch.empty((0, 5 + predictions.shape[1] - 5))

    boxes = torch.tensor(boxes)
    scores = torch.tensor(scores)

    keep = ops.nms(boxes, scores, iou_threshold)
    filtered_preds = []

    for idx in keep:
        pred = predictions[idx].clone()
        pred[4] = scores[idx]  # overwrite with actual used score (conf class prob)
        filtered_preds.append(pred)
    
    return torch.stack(filtered_preds)

# %% [markdown]
# ### Visualize Outputs

# %%
import matplotlib.pyplot as plt
import random

# Collect all test samples into memory for random access
all_images = []
all_targets = []

for images, targets in test_loader:
    all_images.extend(images)
    all_targets.extend(targets)

# Choose N random indices
N = 4
indices = random.sample(range(len(all_images)), k=N)

fig, axs = plt.subplots(1, N, figsize=(5 * N, 5))
if N == 1:
    axs = [axs]

model.eval()
for i, idx in enumerate(indices):
    image = all_images[idx].unsqueeze(0).to(next(model.parameters()).device)
    target = all_targets[idx].to(image.device)

    with torch.no_grad():
        output = model(image)[0].cpu()

    img = image[0].cpu().permute(1, 2, 0).numpy()
    img = (img - img.min()) / (img.max() - img.min() + 1e-5)
    ax = axs[i]
    ax.imshow(img)
    ax.axis("off")
    ax.set_title(f"Random Sample {idx}")

    # Draw predicted and ground truth boxes
    output = output.view(-1, output.shape[-1])
    output = apply_nms(output, iou_threshold=TEST_IOU_THRESHOLD, conf_threshold=TEST_CONFIDENCE_THRESHOLD)
    draw_bounding_boxes(ax, target.cpu(), img.shape[:2], CLASSES, color="red", is_prediction=False)
    draw_bounding_boxes(ax, output, img.shape[:2], CLASSES, color="lime", is_prediction=True)

plt.tight_layout()
plt.show()
